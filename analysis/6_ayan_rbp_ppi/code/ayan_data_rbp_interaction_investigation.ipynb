# %% [markdown]
# # Investigation Into Modeling of both:
# * `RBP Protein-Protein Interactions`
# * `Feature-Feature Statistical Interactions`

# %% [markdown]
# ## Purpose:
#
# {TODO}

# %%
from IPython.core.interactiveshell import InteractiveShell
InteractiveShell.ast_node_interactivity = "all"

import pandas as pd
pd.set_option('display.max_rows', 1000000)
pd.set_option('display.max_columns', 1000000)
pd.set_option('display.max_colwidth', 10000000)

import polars as pl 
_=pl.Config.set_tbl_cols(100000)
_=pl.Config.set_tbl_rows(100000)
_=pl.Config.set_tbl_width_chars(10000)

# %load_ext autoreload 
# %autoreload 2
    
import importlib

RbpInteractionAnalyzer = getattr(
    importlib.import_module("rbp_interaction_analyzer"), 
    "RbpInteractionAnalyzer"
)

# %% [markdown]
# <h1 style="color: teal; font-weight: bold; font-size: 48px;">Initialize Class</h1>

# %%
best_performing_distance_threshold = 100

# %%
analyzer =  RbpInteractionAnalyzer(
    distance_threshold = best_performing_distance_threshold
)
# Out:
# 2025-01-22 16:23:03.669 | SUCCESS  | rbp_interaction_analyzer:load_RBP_PPI_pairs:62 - FROM CACHE: RBP PPI info loaded
#  RBP PPIs in K562: 55
# RBP PPIs in HepG2: 39

# %%
analyzer.retrieve_rbp_ppi_events_and_controls(test_only=False)

analyzer.xgboost_ppi["K562"].tail()
# Out:
# 2025-01-22 16:23:03.753 | INFO     | rbp_interaction_analyzer:retrieve_rbp_ppi_events_and_controls:449 - FROM CACHE: Loading ----ALL---- RBP PPI events and controls.
# Could not memory_map compressed IPC file, defaulting to normal read. Toggle off 'memory_map' to silence this warning.
# Could not memory_map compressed IPC file, defaulting to normal read. Toggle off 'memory_map' to silence this warning.
# Could not memory_map compressed IPC file, defaulting to normal read. Toggle off 'memory_map' to silence this warning.
# Could not memory_map compressed IPC file, defaulting to normal read. Toggle off 'memory_map' to silence this warning.
# 2025-01-22 16:23:31.695 | INFO     | rbp_interaction_analyzer:retrieve_rbp_ppi_events_and_controls:514 - K562
# Linear PPI shape: (8123462, 855) | XGBoost PPI shape: (8123462, 1689)
# 2025-01-22 16:23:32.786 | INFO     | rbp_interaction_analyzer:retrieve_rbp_ppi_events_and_controls:514 - HepG2
# ...

# %%
analyzer.retrieve_rbp_ppi_events_and_controls(test_only=True)

analyzer.xgboost_ppi["K562"].tail()

# %% [markdown]
# ## Which `RBPs` in our `eCLIP` data were not tested in the `Rec-Y2H` paper?

# %%
# analyzer.check_non_tested_RBPs()

# %% [markdown]
# ## Does each unique exon in CTRL data have the same binding graph? If not, what is the distribution of the number of different graphs for each unique upstream, middle, and downstream exon combination?

# %%
# analyzer.plot_mismatch_graphs()

# %% [markdown]
# ## Does the amount of binding correlate with PSI?
#
# This is important if we just take "all other" non-PPI rows and use that as a control as we might have to control downstream for amount of binding in this category.

# %%
# analyzer.amount_binding_vs_PSI()

# %% [markdown]
# ## What is the distribution of number of `Same Position PPI` events per Pair-Position Combination?

# %%
analyzer.plot_same_pos_ppi_per_pair_combination()

# %% [markdown]
# <h1 style="color: crimson; font-weight: bold; font-size: 48px;">Protein-Protein Interactions</h1>

# %% [markdown]
# <h1 style="color: teal; font-weight: bold; font-size: 48px;">Performance of Models on PPI vs Non-PPI Data</h1>

# %% [markdown]
# ## Summary Across Entire Dataset

# %%
analyzer.calculate_summary_PPI_performance()

# %%
analyzer.plot_summary_PPI_performance()

# %% [markdown]
# ## Pair-Position Combination `R2` Scores

# %%
analyzer.calculate_pair_position_combination_r2_scores()

# %%
analyzer.plot_global_pair_position_combination_r2_scores()

# %% [markdown]
# ## Plot Number of Bindings vs. R2 for `Pair-Positions` w/ Largest Difference in `Same Pos. PPI` - `Single Binders`

# %%
# analyzer.create_and_plot_num_bindings_vs_r2_score()

# %% [markdown]
# <h1 style="color: teal; font-weight: bold; font-size: 48px;">Create Table of Same Pos. PPI vs Single Binders Comparisons</h1>

# %% [markdown]
# ## Compare `PPI` vs `Single Binder` per `Pair-Position Combination` for `R2 Score`

# %%
analyzer.compare_ppi_vs_single_binder_r2_table()

# %%
analyzer.plot_pair_position_category_line_r2_scores()

# %% [markdown]
# ## Compare `PPI` to either `Single Binder` or each individual binder per `Pair-Position Combination` across several metrics and tests

# %%
analyzer.create_ppi_vs_single_binders_table()

# %% [markdown]
# <h1 style="color: teal; font-weight: bold; font-size: 48px;">Performance + SHAP Plot per PAIR-POSITION</h1>

# %% [markdown]
# ## `Pair-Position Combo` Performance + `SHAP` Distribution Plots

# %%
analyzer.plot_pair_position_performance_and_local_shap()

# %% [markdown]
# <h1 style="color: teal; font-weight: bold; font-size: 48px;">PPI OLS Linear Regression & Parameter Significance Testing</h1>

# %% [markdown]
# ## **LARGE** `OLS Linear Regression`: All original `binding features` and `interaction terms (same and all position)`

# %%
analyzer.run_all_ppi_features_and_interaction_term_ols_linear_regression()

# %% [markdown]
# ## Per `pair-position combo`

# %%
analyzer.run_individual_interaction_term_ols_linear_regressions()
# Out:
# 2025-01-22 16:24:48.985 | INFO     | rbp_interaction_analyzer:run_individual_interaction_term_ols_linear_regressions:1788 - NO CACHE... hence, running OLS linear regression per pair-position combo for coefficient testing using ALL data
# Could not memory_map compressed IPC file, defaulting to normal read. Toggle off 'memory_map' to silence this warning.
# Processing K562 interactions: 100%|██████████| 1584/1584 [03:16<00:00,  8.07it/s]
# Could not memory_map compressed IPC file, defaulting to normal read. Toggle off 'memory_map' to silence this warning.
# Processing HepG2 interactions: 100%|██████████| 972/972 [02:08<00:00,  7.59it/s]

# %% [markdown]
# #### Merge the above 2 tables into a more usable table

# %%
analyzer.merge_interaction_term_regression_tables()
# Out:
# 2025-01-22 16:47:46.094 | INFO     | rbp_interaction_analyzer:merge_interaction_term_regression_tables:1843 - Aggregating regression tables and statistics for All Position PPIs.
#                                  Same Position  K562 - # Interaction Rows  \
# Interaction Term
# APOBEC3C-1_HNRNPK-1_interaction           True                        0.0
# APOBEC3C-1_HNRNPK-2_interaction          False                        0.0
# APOBEC3C-1_HNRNPK-3_interaction          False                       11.0
# APOBEC3C-1_HNRNPK-4_interaction          False                        0.0
# APOBEC3C-1_HNRNPK-5_interaction          False                       37.0
# APOBEC3C-1_HNRNPK-6_interaction          False                       49.0
# APOBEC3C-1_PCBP1-1_interaction            True                      562.0
# APOBEC3C-1_PCBP1-2_interaction           False                      408.0
# APOBEC3C-1_PCBP1-3_interaction           False                       37.0
# ...

# %% [markdown]
# <h1 style="color: teal; font-weight: bold; font-size: 48px;">Downstream Analysis of "All Term" OLS Linear Regression Results</h1>

# %% [markdown]
# ## `Actual` vs `Predicted PSI` for `All Term` Models Trained w/ `Train + Validate`

# %%
analyzer.plot_all_term_ppi_ols_lin_reg_performance()

# %% [markdown]
# ## `PSI` & `Local SHAP` Distributions per `"Interaction Term"`

# %%
analyzer.plot_all_position_ppi_interaction_psi_distributions_and_local_SHAP()

# %% [markdown]
# ## Global Heatmap of Interaction Terms Betas & Significance

# %%
analyzer.plot_summary_beta_coefficient_and_significance_from_all_term_ols_lin_reg()

# %% [markdown]
# ## "Meta-Table" Combining Complex Regressions with Simple Regressions and Some Descriptive Statistics

# %%
analyzer.merge_interaction_term_regression_tables()

# %% [markdown]
# <h1 style="color: teal; font-weight: bold; font-size: 48px;">Miscellaneous Specific/Tailored Analyses</h1>

# %% [markdown]
# ## Plot `SRSF` & `HNRNP` Proteins

# %%
analyzer.delete_PPI_data()

# %%
analyzer.retrieve_rbp_ppi_events_and_controls(test_only=False)

# %%
analyzer.plot_srsf_and_hnrnp_local_shap_distributions()

# %% [markdown]
# <h1 style="color: crimson; font-weight: bold; font-size: 48px;">Feature-Feature Statistical Interactions</h1>

# %%
analyzer.create_feature_interaction_r2_table()
