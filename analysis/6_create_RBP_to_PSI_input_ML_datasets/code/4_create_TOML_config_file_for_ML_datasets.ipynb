# %% [markdown]
# # Create `YAML` Config File for `RBP ML` Input Data

# %% [markdown]
# ## Purpose:
#
# Describe the configuration of:
# * `Cell Lines`
# * `Peak Distance Thresholds`
# * `Data Creation Method`
#
# that went into creating each dataset and provide an easy-to-parse dictionary of all possible combinations of datasets.

# %% [markdown]
# ## Packages and Options

# %%
import glob, os, yaml

from IPython.core.interactiveshell import InteractiveShell
InteractiveShell.ast_node_interactivity = "all"

# %% [markdown]
# ## Literals

# %%
files = glob.glob("../final_modeling_input_datasets/*.tsv.gz")
yaml_dict = {}

# %% [markdown]
# ## Define Covariates

# %%
cell_lines = sorted(list(set([file.split("/")[-1].split("_")[0] for file in files])))
cell_lines

yaml_dict["Cell Lines"] = cell_lines 

thresholds = sorted(list(set([file.split("/")[-1].split("_")[1] for file in files])))
thresholds

yaml_dict["Peak Distance Thresholds"] = thresholds

analysis_methods = sorted(list(set(["_".join(file.split("/")[-1].split(".")[0].split("_")[2:]) for file in files])))
analysis_methods

yaml_dict["Data Creation Methods"] = analysis_methods
# Out:
# ['HepG2', 'K562']
# ['100', '1000', '10000', '2000', '50', '500', '5000']
# ['binary-binding-only',
#  'expression-getmm_no-log_dose-dependent-expression',
#  'expression-getmm_no-log_dose-independent-expression',
#  'expression-getmm_yes-log_dose-dependent-expression',
#  'expression-getmm_yes-log_dose-independent-expression',
#  'expression-tmm_no-log_dose-dependent-expression',
#  'expression-tmm_no-log_dose-independent-expression',
#  'expression-tmm_yes-log_dose-dependent-expression',
#  'expression-tmm_yes-log_dose-independent-expression',
#  'num-peaks-only']

# %% [markdown]
# ## Iterate Through All Combinations of Covariates and Label Data File

# %%
yaml_dict["Data Files"] = {}

encountered_files = set()

for cell_line in cell_lines: 
    yaml_dict["Data Files"][cell_line] = {}

    for threshold in thresholds: 
        yaml_dict["Data Files"][cell_line][threshold] = {}

        for analysis_method in analysis_methods:
            
            # get the file matching the covariates
            file = glob.glob("../final_modeling_input_datasets/{}_{}_{}*".format(cell_line, threshold, analysis_method))
            assert len(file)==1
            
            # make sure that we aren't picking up on duplicate files 
            assert os.path.abspath(file[0]) not in encountered_files
            # add the absolute path of the data file to files we've seen before  
            encountered_files.add(os.path.abspath(file[0]))
            
            # save absolute path of data file to dictionary 
            yaml_dict["Data Files"][cell_line][threshold][analysis_method] =  os.path.abspath(file[0])

# %% [markdown]
# ## Create `YAML` File from `Dict`

# %%
with open("../final_modeling_input_datasets/data_config.yaml", 'w') as out_file: 
    _=yaml.dump(yaml_dict, out_file)

# %% [markdown]
# ## Test `YAML` File `Dict` Conversion Ability

# %%
with open("../final_modeling_input_datasets/data_config.yaml", 'r') as yaml_file: 
    test_dict = yaml.safe_load(yaml_file)
    
test_dict
# Out:
# {'Cell Lines': ['HepG2', 'K562'],
#  'Data Creation Methods': ['binary-binding-only',
#   'expression-getmm_no-log_dose-dependent-expression',
#   'expression-getmm_no-log_dose-independent-expression',
#   'expression-getmm_yes-log_dose-dependent-expression',
#   'expression-getmm_yes-log_dose-independent-expression',
#   'expression-tmm_no-log_dose-dependent-expression',
#   'expression-tmm_no-log_dose-independent-expression',
#   'expression-tmm_yes-log_dose-dependent-expression',
#   'expression-tmm_yes-log_dose-independent-expression',
#   'num-peaks-only'],
#  'Data Files': {'HepG2': {'100': {'binary-binding-only': '/sfs/gpfs/tardis/project/PlatigLab/users/yogi/ENCODE-RNA-Binding-Protein-Network-Modeling/analysis/6_create_RBP_to_PSI_input_ML_datasets/final_modeling_input_datasets/HepG2_100_binary-binding-only.tsv.gz',
#     'expression-getmm_no-log_dose-dependent-expression': '/sfs/gpfs/tardis/project/PlatigLab/users/yogi/ENCODE-RNA-Binding-Protein-Network-Modeling/analysis/6_create_RBP_to_PSI_input_ML_datasets/final_modeling_input_datasets/HepG2_100_expression-getmm_no-log_dose-dependent-expression.tsv.gz',
#     'expression-getmm_no-log_dose-independent-expression': '/sfs/gpfs/tardis/project/PlatigLab/users/yogi/ENCODE-RNA-Binding-Protein-Network-Modeling/analysis/6_create_RBP_to_PSI_input_ML_datasets/final_modeling_input_datasets/HepG2_100_expression-getmm_no-log_dose-independent-expression.tsv.gz',
#     'expression-getmm_yes-log_dose-dependent-expression': '/sfs/gpfs/tardis/project/PlatigLab/users/yogi/ENCODE-RNA-Binding-Protein-Network-Modeling/analysis/6_create_RBP_to_PSI_input_ML_datasets/final_modeling_input_datasets/HepG2_100_expression-getmm_yes-log_dose-dependent-expression.tsv.gz',
#     'expression-getmm_yes-log_dose-independent-expression': '/sfs/gpfs/tardis/project/PlatigLab/users/yogi/ENCODE-RNA-Binding-Protein-Network-Modeling/analysis/6_create_RBP_to_PSI_input_ML_datasets/final_modeling_input_datasets/HepG2_100_expression-getmm_yes-log_dose-independent-expression.tsv.gz',
#     'expression-tmm_no-log_dose-dependent-expression': '/sfs/gpfs/tardis/project/PlatigLab/users/yogi/ENCODE-RNA-Binding-Protein-Network-Modeling/analysis/6_create_RBP_to_PSI_input_ML_datasets/final_modeling_input_datasets/HepG2_100_expression-tmm_no-log_dose-dependent-expression.tsv.gz',
#     'expression-tmm_no-log_dose-independent-expression': '/sfs/gpfs/tardis/project/PlatigLab/users/yogi/ENCODE-RNA-Binding-Protein-Network-Modeling/analysis/6_create_RBP_to_PSI_input_ML_datasets/final_modeling_input_datasets/HepG2_100_expression-tmm_no-log_dose-independent-expression.tsv.gz',
#     'expression-tmm_yes-log_dose-dependent-expression': '/sfs/gpfs/tardis/project/PlatigLab/users/yogi/ENCODE-RNA-Binding-Protein-Network-Modeling/analysis/6_create_RBP_to_PSI_input_ML_datasets/final_modeling_input_datasets/HepG2_100_expression-tmm_yes-log_dose-dependent-expression.tsv.gz',
#     'expression-tmm_yes-log_dose-independent-expression': '/sfs/gpfs/tardis/project/PlatigLab/users/yogi/ENCODE-RNA-Binding-Protein-Network-Modeling/analysis/6_create_RBP_to_PSI_input_ML_datasets/final_modeling_input_datasets/HepG2_100_expression-tmm_yes-log_dose-independent-expression.tsv.gz',
#     'num-peaks-only': '/sfs/gpfs/tardis/project/PlatigLab/users/yogi/ENCODE-RNA-Binding-Protein-Network-Modeling/analysis/6_create_RBP_to_PSI_input_ML_datasets/final_modeling_input_datasets/HepG2_100_num-peaks-only.tsv.gz'},
#    '1000': {'binary-binding-only': '/sfs/gpfs/tardis/project/PlatigLab/users/yogi/ENCODE-RNA-Binding-Protein-Network-Modeling/analysis/6_create_RBP_to_PSI_input_ML_datasets/final_modeling_input_datasets/HepG2_1000_binary-binding-only.tsv.gz',
#     'expression-getmm_no-log_dose-dependent-expression': '/sfs/gpfs/tardis/project/PlatigLab/users/yogi/ENCODE-RNA-Binding-Protein-Network-Modeling/analysis/6_create_RBP_to_PSI_input_ML_datasets/final_modeling_input_datasets/HepG2_1000_expression-getmm_no-log_dose-dependent-expression.tsv.gz',
#     'expression-getmm_no-log_dose-independent-expression': '/sfs/gpfs/tardis/project/PlatigLab/users/yogi/ENCODE-RNA-Binding-Protein-Network-Modeling/analysis/6_create_RBP_to_PSI_input_ML_datasets/final_modeling_input_datasets/HepG2_1000_expression-getmm_no-log_dose-independent-expression.tsv.gz',
#     'expression-getmm_yes-log_dose-dependent-expression': '/sfs/gpfs/tardis/project/PlatigLab/users/yogi/ENCODE-RNA-Binding-Protein-Network-Modeling/analysis/6_create_RBP_to_PSI_input_ML_datasets/final_modeling_input_datasets/HepG2_1000_expression-getmm_yes-log_dose-dependent-expression.tsv.gz',
#     'expression-getmm_yes-log_dose-independent-expression': '/sfs/gpfs/tardis/project/PlatigLab/users/yogi/ENCODE-RNA-Binding-Protein-Network-Modeling/analysis/6_create_RBP_to_PSI_input_ML_datasets/final_modeling_input_datasets/HepG2_1000_expression-getmm_yes-log_dose-independent-expression.tsv.gz',
#     'expression-tmm_no-log_dose-dependent-expression': '/sfs/gpfs/tardis/project/PlatigLab/users/yogi/ENCODE-RNA-Binding-Protein-Network-Modeling/analysis/6_create_RBP_to_PSI_input_ML_datasets/final_modeling_input_datasets/HepG2_1000_expression-tmm_no-log_dose-dependent-expression.tsv.gz',
#     'expression-tmm_no-log_dose-independent-expression': '/sfs/gpfs/tardis/project/PlatigLab/users/yogi/ENCODE-RNA-Binding-Protein-Network-Modeling/analysis/6_create_RBP_to_PSI_input_ML_datasets/final_modeling_input_datasets/HepG2_1000_expression-tmm_no-log_dose-independent-expression.tsv.gz',
#     'expression-tmm_yes-log_dose-dependent-expression': '/sfs/gpfs/tardis/project/PlatigLab/users/yogi/ENCODE-RNA-Binding-Protein-Network-Modeling/analysis/6_create_RBP_to_PSI_input_ML_datasets/final_modeling_input_datasets/HepG2_1000_expression-tmm_yes-log_dose-dependent-expression.tsv.gz',
#     'expression-tmm_yes-log_dose-independent-expression': '/sfs/gpfs/tardis/project/PlatigLab/users/yogi/ENCODE-RNA-Binding-Protein-Network-Modeling/analysis/6_create_RBP_to_PSI_input_ML_datasets/final_modeling_input_datasets/HepG2_1000_expression-tmm_yes-log_dose-independent-expression.tsv.gz',
#     'num-peaks-only': '/sfs/gpfs/tardis/project/PlatigLab/users/yogi/ENCODE-RNA-Binding-Protein-Network-Modeling/analysis/6_create_RBP_to_PSI_input_ML_datasets/final_modeling_input_datasets/HepG2_1000_num-peaks-only.tsv.gz'},
#    '10000': {'binary-binding-only': '/sfs/gpfs/tardis/project/PlatigLab/users/yogi/ENCODE-RNA-Binding-Protein-Network-Modeling/analysis/6_create_RBP_to_PSI_input_ML_datasets/final_modeling_input_datasets/HepG2_10000_binary-binding-only.tsv.gz',
#     'expression-getmm_no-log_dose-dependent-expression': '/sfs/gpfs/tardis/project/PlatigLab/users/yogi/ENCODE-RNA-Binding-Protein-Network-Modeling/analysis/6_create_RBP_to_PSI_input_ML_datasets/final_modeling_input_datasets/HepG2_10000_expression-getmm_no-log_dose-dependent-expression.tsv.gz',
#     'expression-getmm_no-log_dose-independent-expression': '/sfs/gpfs/tardis/project/PlatigLab/users/yogi/ENCODE-RNA-Binding-Protein-Network-Modeling/analysis/6_create_RBP_to_PSI_input_ML_datasets/final_modeling_input_datasets/HepG2_10000_expression-getmm_no-log_dose-independent-expression.tsv.gz',
#     'expression-getmm_yes-log_dose-dependent-expression': '/sfs/gpfs/tardis/project/PlatigLab/users/yogi/ENCODE-RNA-Binding-Protein-Network-Modeling/analysis/6_create_RBP_to_PSI_input_ML_datasets/final_modeling_input_datasets/HepG2_10000_expression-getmm_yes-log_dose-dependent-expression.tsv.gz',
#     'expression-getmm_yes-log_dose-independent-expression': '/sfs/gpfs/tardis/project/PlatigLab/users/yogi/ENCODE-RNA-Binding-Protein-Network-Modeling/analysis/6_create_RBP_to_PSI_input_ML_datasets/final_modeling_input_datasets/HepG2_10000_expression-getmm_yes-log_dose-independent-expression.tsv.gz',
#     'expression-tmm_no-log_dose-dependent-expression': '/sfs/gpfs/tardis/project/PlatigLab/users/yogi/ENCODE-RNA-Binding-Protein-Network-Modeling/analysis/6_create_RBP_to_PSI_input_ML_datasets/final_modeling_input_datasets/HepG2_10000_expression-tmm_no-log_dose-dependent-expression.tsv.gz',
#     'expression-tmm_no-log_dose-independent-expression': '/sfs/gpfs/tardis/project/PlatigLab/users/yogi/ENCODE-RNA-Binding-Protein-Network-Modeling/analysis/6_create_RBP_to_PSI_input_ML_datasets/final_modeling_input_datasets/HepG2_10000_expression-tmm_no-log_dose-independent-expression.tsv.gz',
#     'expression-tmm_yes-log_dose-dependent-expression': '/sfs/gpfs/tardis/project/PlatigLab/users/yogi/ENCODE-RNA-Binding-Protein-Network-Modeling/analysis/6_create_RBP_to_PSI_input_ML_datasets/final_modeling_input_datasets/HepG2_10000_expression-tmm_yes-log_dose-dependent-expression.tsv.gz',
#     'expression-tmm_yes-log_dose-independent-expression': '/sfs/gpfs/tardis/project/PlatigLab/users/yogi/ENCODE-RNA-Binding-Protein-Network-Modeling/analysis/6_create_RBP_to_PSI_input_ML_datasets/final_modeling_input_datasets/HepG2_10000_expression-tmm_yes-log_dose-independent-expression.tsv.gz',
#     'num-peaks-only': '/sfs/gpfs/tardis/project/PlatigLab/users/yogi/ENCODE-RNA-Binding-Protein-Network-Modeling/analysis/6_create_RBP_to_PSI_input_ML_datasets/final_modeling_input_datasets/HepG2_10000_num-peaks-only.tsv.gz'},
#    '2000': {'binary-binding-only': '/sfs/gpfs/tardis/project/PlatigLab/users/yogi/ENCODE-RNA-Binding-Protein-Network-Modeling/analysis/6_create_RBP_to_PSI_input_ML_datasets/final_modeling_input_datasets/HepG2_2000_binary-binding-only.tsv.gz',
#     'expression-getmm_no-log_dose-dependent-expression': '/sfs/gpfs/tardis/project/PlatigLab/users/yogi/ENCODE-RNA-Binding-Protein-Network-Modeling/analysis/6_create_RBP_to_PSI_input_ML_datasets/final_modeling_input_datasets/HepG2_2000_expression-getmm_no-log_dose-dependent-expression.tsv.gz',
#     'expression-getmm_no-log_dose-independent-expression': '/sfs/gpfs/tardis/project/PlatigLab/users/yogi/ENCODE-RNA-Binding-Protein-Network-Modeling/analysis/6_create_RBP_to_PSI_input_ML_datasets/final_modeling_input_datasets/HepG2_2000_expression-getmm_no-log_dose-independent-expression.tsv.gz',
#     'expression-getmm_yes-log_dose-dependent-expression': '/sfs/gpfs/tardis/project/PlatigLab/users/yogi/ENCODE-RNA-Binding-Protein-Network-Modeling/analysis/6_create_RBP_to_PSI_input_ML_datasets/final_modeling_input_datasets/HepG2_2000_expression-getmm_yes-log_dose-dependent-expression.tsv.gz',
#     'expression-getmm_yes-log_dose-independent-expression': '/sfs/gpfs/tardis/project/PlatigLab/users/yogi/ENCODE-RNA-Binding-Protein-Network-Modeling/analysis/6_create_RBP_to_PSI_input_ML_datasets/final_modeling_input_datasets/HepG2_2000_expression-getmm_yes-log_dose-independent-expression.tsv.gz',
#     'expression-tmm_no-log_dose-dependent-expression': '/sfs/gpfs/tardis/project/PlatigLab/users/yogi/ENCODE-RNA-Binding-Protein-Network-Modeling/analysis/6_create_RBP_to_PSI_input_ML_datasets/final_modeling_input_datasets/HepG2_2000_expression-tmm_no-log_dose-dependent-expression.tsv.gz',
#     'expression-tmm_no-log_dose-independent-expression': '/sfs/gpfs/tardis/project/PlatigLab/users/yogi/ENCODE-RNA-Binding-Protein-Network-Modeling/analysis/6_create_RBP_to_PSI_input_ML_datasets/final_modeling_input_datasets/HepG2_2000_expression-tmm_no-log_dose-independent-expression.tsv.gz',
#     'expression-tmm_yes-log_dose-dependent-expression': '/sfs/gpfs/tardis/project/PlatigLab/users/yogi/ENCODE-RNA-Binding-Protein-Network-Modeling/analysis/6_create_RBP_to_PSI_input_ML_datasets/final_modeling_input_datasets/HepG2_2000_expression-tmm_yes-log_dose-dependent-expression.tsv.gz',
#     'expression-tmm_yes-log_dose-independent-expression': '/sfs/gpfs/tardis/project/PlatigLab/users/yogi/ENCODE-RNA-Binding-Protein-Network-Modeling/analysis/6_create_RBP_to_PSI_input_ML_datasets/final_modeling_input_datasets/HepG2_2000_expression-tmm_yes-log_dose-independent-expression.tsv.gz',
#     'num-peaks-only': '/sfs/gpfs/tardis/project/PlatigLab/users/yogi/ENCODE-RNA-Binding-Protein-Network-Modeling/analysis/6_create_RBP_to_PSI_input_ML_datasets/final_modeling_input_datasets/HepG2_2000_num-peaks-only.tsv.gz'},
#    '50': {'binary-binding-only': '/sfs/gpfs/tardis/project/PlatigLab/users/yogi/ENCODE-RNA-Binding-Protein-Network-Modeling/analysis/6_create_RBP_to_PSI_input_ML_datasets/final_modeling_input_datasets/HepG2_50_binary-binding-only.tsv.gz',
#     'expression-getmm_no-log_dose-dependent-expression': '/sfs/gpfs/tardis/project/PlatigLab/users/yogi/ENCODE-RNA-Binding-Protein-Network-Modeling/analysis/6_create_RBP_to_PSI_input_ML_datasets/final_modeling_input_datasets/HepG2_50_expression-getmm_no-log_dose-dependent-expression.tsv.gz',
#     'expression-getmm_no-log_dose-independent-expression': '/sfs/gpfs/tardis/project/PlatigLab/users/yogi/ENCODE-RNA-Binding-Protein-Network-Modeling/analysis/6_create_RBP_to_PSI_input_ML_datasets/final_modeling_input_datasets/HepG2_50_expression-getmm_no-log_dose-independent-expression.tsv.gz',
#     'expression-getmm_yes-log_dose-dependent-expression': '/sfs/gpfs/tardis/project/PlatigLab/users/yogi/ENCODE-RNA-Binding-Protein-Network-Modeling/analysis/6_create_RBP_to_PSI_input_ML_datasets/final_modeling_input_datasets/HepG2_50_expression-getmm_yes-log_dose-dependent-expression.tsv.gz',
#     'expression-getmm_yes-log_dose-independent-expression': '/sfs/gpfs/tardis/project/PlatigLab/users/yogi/ENCODE-RNA-Binding-Protein-Network-Modeling/analysis/6_create_RBP_to_PSI_input_ML_datasets/final_modeling_input_datasets/HepG2_50_expression-getmm_yes-log_dose-independent-expression.tsv.gz',
#     'expression-tmm_no-log_dose-dependent-expression': '/sfs/gpfs/tardis/project/PlatigLab/users/yogi/ENCODE-RNA-Binding-Protein-Network-Modeling/analysis/6_create_RBP_to_PSI_input_ML_datasets/final_modeling_input_datasets/HepG2_50_expression-tmm_no-log_dose-dependent-expression.tsv.gz',
#     'expression-tmm_no-log_dose-independent-expression': '/sfs/gpfs/tardis/project/PlatigLab/users/yogi/ENCODE-RNA-Binding-Protein-Network-Modeling/analysis/6_create_RBP_to_PSI_input_ML_datasets/final_modeling_input_datasets/HepG2_50_expression-tmm_no-log_dose-independent-expression.tsv.gz',
#     'expression-tmm_yes-log_dose-dependent-expression': '/sfs/gpfs/tardis/project/PlatigLab/users/yogi/ENCODE-RNA-Binding-Protein-Network-Modeling/analysis/6_create_RBP_to_PSI_input_ML_datasets/final_modeling_input_datasets/HepG2_50_expression-tmm_yes-log_dose-dependent-expression.tsv.gz',
#     'expression-tmm_yes-log_dose-independent-expression': '/sfs/gpfs/tardis/project/PlatigLab/users/yogi/ENCODE-RNA-Binding-Protein-Network-Modeling/analysis/6_create_RBP_to_PSI_input_ML_datasets/final_modeling_input_datasets/HepG2_50_expression-tmm_yes-log_dose-independent-expression.tsv.gz',
#     'num-peaks-only': '/sfs/gpfs/tardis/project/PlatigLab/users/yogi/ENCODE-RNA-Binding-Protein-Network-Modeling/analysis/6_create_RBP_to_PSI_input_ML_datasets/final_modeling_input_datasets/HepG2_50_num-peaks-only.tsv.gz'},
#    '500': {'binary-binding-only': '/sfs/gpfs/tardis/project/PlatigLab/users/yogi/ENCODE-RNA-Binding-Protein-Network-Modeling/analysis/6_create_RBP_to_PSI_input_ML_datasets/final_modeling_input_datasets/HepG2_500_binary-binding-only.tsv.gz',
#     'expression-getmm_no-log_dose-dependent-expression': '/sfs/gpfs/tardis/project/PlatigLab/users/yogi/ENCODE-RNA-Binding-Protein-Network-Modeling/analysis/6_create_RBP_to_PSI_input_ML_datasets/final_modeling_input_datasets/HepG2_500_expression-getmm_no-log_dose-dependent-expression.tsv.gz',
#     'expression-getmm_no-log_dose-independent-expression': '/sfs/gpfs/tardis/project/PlatigLab/users/yogi/ENCODE-RNA-Binding-Protein-Network-Modeling/analysis/6_create_RBP_to_PSI_input_ML_datasets/final_modeling_input_datasets/HepG2_500_expression-getmm_no-log_dose-independent-expression.tsv.gz',
#     'expression-getmm_yes-log_dose-dependent-expression': '/sfs/gpfs/tardis/project/PlatigLab/users/yogi/ENCODE-RNA-Binding-Protein-Network-Modeling/analysis/6_create_RBP_to_PSI_input_ML_datasets/final_modeling_input_datasets/HepG2_500_expression-getmm_yes-log_dose-dependent-expression.tsv.gz',
#     'expression-getmm_yes-log_dose-independent-expression': '/sfs/gpfs/tardis/project/PlatigLab/users/yogi/ENCODE-RNA-Binding-Protein-Network-Modeling/analysis/6_create_RBP_to_PSI_input_ML_datasets/final_modeling_input_datasets/HepG2_500_expression-getmm_yes-log_dose-independent-expression.tsv.gz',
#     'expression-tmm_no-log_dose-dependent-expression': '/sfs/gpfs/tardis/project/PlatigLab/users/yogi/ENCODE-RNA-Binding-Protein-Network-Modeling/analysis/6_create_RBP_to_PSI_input_ML_datasets/final_modeling_input_datasets/HepG2_500_expression-tmm_no-log_dose-dependent-expression.tsv.gz',
#     'expression-tmm_no-log_dose-independent-expression': '/sfs/gpfs/tardis/project/PlatigLab/users/yogi/ENCODE-RNA-Binding-Protein-Network-Modeling/analysis/6_create_RBP_to_PSI_input_ML_datasets/final_modeling_input_datasets/HepG2_500_expression-tmm_no-log_dose-independent-expression.tsv.gz',
#     'expression-tmm_yes-log_dose-dependent-expression': '/sfs/gpfs/tardis/project/PlatigLab/users/yogi/ENCODE-RNA-Binding-Protein-Network-Modeling/analysis/6_create_RBP_to_PSI_input_ML_datasets/final_modeling_input_datasets/HepG2_500_expression-tmm_yes-log_dose-dependent-expression.tsv.gz',
#     'expression-tmm_yes-log_dose-independent-expression': '/sfs/gpfs/tardis/project/PlatigLab/users/yogi/ENCODE-RNA-Binding-Protein-Network-Modeling/analysis/6_create_RBP_to_PSI_input_ML_datasets/final_modeling_input_datasets/HepG2_500_expression-tmm_yes-log_dose-independent-expression.tsv.gz',
#     'num-peaks-only': '/sfs/gpfs/tardis/project/PlatigLab/users/yogi/ENCODE-RNA-Binding-Protein-Network-Modeling/analysis/6_create_RBP_to_PSI_input_ML_datasets/final_modeling_input_datasets/HepG2_500_num-peaks-only.tsv.gz'},
#    '5000': {'binary-binding-only': '/sfs/gpfs/tardis/project/PlatigLab/users/yogi/ENCODE-RNA-Binding-Protein-Network-Modeling/analysis/6_create_RBP_to_PSI_input_ML_datasets/final_modeling_input_datasets/HepG2_5000_binary-binding-only.tsv.gz',
#     'expression-getmm_no-log_dose-dependent-expression': '/sfs/gpfs/tardis/project/PlatigLab/users/yogi/ENCODE-RNA-Binding-Protein-Network-Modeling/analysis/6_create_RBP_to_PSI_input_ML_datasets/final_modeling_input_datasets/HepG2_5000_expression-getmm_no-log_dose-dependent-expression.tsv.gz',
#     'expression-getmm_no-log_dose-independent-expression': '/sfs/gpfs/tardis/project/PlatigLab/users/yogi/ENCODE-RNA-Binding-Protein-Network-Modeling/analysis/6_create_RBP_to_PSI_input_ML_datasets/final_modeling_input_datasets/HepG2_5000_expression-getmm_no-log_dose-independent-expression.tsv.gz',
#     'expression-getmm_yes-log_dose-dependent-expression': '/sfs/gpfs/tardis/project/PlatigLab/users/yogi/ENCODE-RNA-Binding-Protein-Network-Modeling/analysis/6_create_RBP_to_PSI_input_ML_datasets/final_modeling_input_datasets/HepG2_5000_expression-getmm_yes-log_dose-dependent-expression.tsv.gz',
#     'expression-getmm_yes-log_dose-independent-expression': '/sfs/gpfs/tardis/project/PlatigLab/users/yogi/ENCODE-RNA-Binding-Protein-Network-Modeling/analysis/6_create_RBP_to_PSI_input_ML_datasets/final_modeling_input_datasets/HepG2_5000_expression-getmm_yes-log_dose-independent-expression.tsv.gz',
#     'expression-tmm_no-log_dose-dependent-expression': '/sfs/gpfs/tardis/project/PlatigLab/users/yogi/ENCODE-RNA-Binding-Protein-Network-Modeling/analysis/6_create_RBP_to_PSI_input_ML_datasets/final_modeling_input_datasets/HepG2_5000_expression-tmm_no-log_dose-dependent-expression.tsv.gz',
#     'expression-tmm_no-log_dose-independent-expression': '/sfs/gpfs/tardis/project/PlatigLab/users/yogi/ENCODE-RNA-Binding-Protein-Network-Modeling/analysis/6_create_RBP_to_PSI_input_ML_datasets/final_modeling_input_datasets/HepG2_5000_expression-tmm_no-log_dose-independent-expression.tsv.gz',
#     'expression-tmm_yes-log_dose-dependent-expression': '/sfs/gpfs/tardis/project/PlatigLab/users/yogi/ENCODE-RNA-Binding-Protein-Network-Modeling/analysis/6_create_RBP_to_PSI_input_ML_datasets/final_modeling_input_datasets/HepG2_5000_expression-tmm_yes-log_dose-dependent-expression.tsv.gz',
#     'expression-tmm_yes-log_dose-independent-expression': '/sfs/gpfs/tardis/project/PlatigLab/users/yogi/ENCODE-RNA-Binding-Protein-Network-Modeling/analysis/6_create_RBP_to_PSI_input_ML_datasets/final_modeling_input_datasets/HepG2_5000_expression-tmm_yes-log_dose-independent-expression.tsv.gz',
#     'num-peaks-only': '/sfs/gpfs/tardis/project/PlatigLab/users/yogi/ENCODE-RNA-Binding-Protein-Network-Modeling/analysis/6_create_RBP_to_PSI_input_ML_datasets/final_modeling_input_datasets/HepG2_5000_num-peaks-only.tsv.gz'}},
#   'K562': {'100': {'binary-binding-only': '/sfs/gpfs/tardis/project/PlatigLab/users/yogi/ENCODE-RNA-Binding-Protein-Network-Modeling/analysis/6_create_RBP_to_PSI_input_ML_datasets/final_modeling_input_datasets/K562_100_binary-binding-only.tsv.gz',
#     'expression-getmm_no-log_dose-dependent-expression': '/sfs/gpfs/tardis/project/PlatigLab/users/yogi/ENCODE-RNA-Binding-Protein-Network-Modeling/analysis/6_create_RBP_to_PSI_input_ML_datasets/final_modeling_input_datasets/K562_100_expression-getmm_no-log_dose-dependent-expression.tsv.gz',
#     'expression-getmm_no-log_dose-independent-expression': '/sfs/gpfs/tardis/project/PlatigLab/users/yogi/ENCODE-RNA-Binding-Protein-Network-Modeling/analysis/6_create_RBP_to_PSI_input_ML_datasets/final_modeling_input_datasets/K562_100_expression-getmm_no-log_dose-independent-expression.tsv.gz',
#     'expression-getmm_yes-log_dose-dependent-expression': '/sfs/gpfs/tardis/project/PlatigLab/users/yogi/ENCODE-RNA-Binding-Protein-Network-Modeling/analysis/6_create_RBP_to_PSI_input_ML_datasets/final_modeling_input_datasets/K562_100_expression-getmm_yes-log_dose-dependent-expression.tsv.gz',
#     'expression-getmm_yes-log_dose-independent-expression': '/sfs/gpfs/tardis/project/PlatigLab/users/yogi/ENCODE-RNA-Binding-Protein-Network-Modeling/analysis/6_create_RBP_to_PSI_input_ML_datasets/final_modeling_input_datasets/K562_100_expression-getmm_yes-log_dose-independent-expression.tsv.gz',
#     'expression-tmm_no-log_dose-dependent-expression': '/sfs/gpfs/tardis/project/PlatigLab/users/yogi/ENCODE-RNA-Binding-Protein-Network-Modeling/analysis/6_create_RBP_to_PSI_input_ML_datasets/final_modeling_input_datasets/K562_100_expression-tmm_no-log_dose-dependent-expression.tsv.gz',
#     'expression-tmm_no-log_dose-independent-expression': '/sfs/gpfs/tardis/project/PlatigLab/users/yogi/ENCODE-RNA-Binding-Protein-Network-Modeling/analysis/6_create_RBP_to_PSI_input_ML_datasets/final_modeling_input_datasets/K562_100_expression-tmm_no-log_dose-independent-expression.tsv.gz',
#     'expression-tmm_yes-log_dose-dependent-expression': '/sfs/gpfs/tardis/project/PlatigLab/users/yogi/ENCODE-RNA-Binding-Protein-Network-Modeling/analysis/6_create_RBP_to_PSI_input_ML_datasets/final_modeling_input_datasets/K562_100_expression-tmm_yes-log_dose-dependent-expression.tsv.gz',
#     'expression-tmm_yes-log_dose-independent-expression': '/sfs/gpfs/tardis/project/PlatigLab/users/yogi/ENCODE-RNA-Binding-Protein-Network-Modeling/analysis/6_create_RBP_to_PSI_input_ML_datasets/final_modeling_input_datasets/K562_100_expression-tmm_yes-log_dose-independent-expression.tsv.gz',
#     'num-peaks-only': '/sfs/gpfs/tardis/project/PlatigLab/users/yogi/ENCODE-RNA-Binding-Protein-Network-Modeling/analysis/6_create_RBP_to_PSI_input_ML_datasets/final_modeling_input_datasets/K562_100_num-peaks-only.tsv.gz'},
#    '1000': {'binary-binding-only': '/sfs/gpfs/tardis/project/PlatigLab/users/yogi/ENCODE-RNA-Binding-Protein-Network-Modeling/analysis/6_create_RBP_to_PSI_input_ML_datasets/final_modeling_input_datasets/K562_1000_binary-binding-only.tsv.gz',
#     'expression-getmm_no-log_dose-dependent-expression': '/sfs/gpfs/tardis/project/PlatigLab/users/yogi/ENCODE-RNA-Binding-Protein-Network-Modeling/analysis/6_create_RBP_to_PSI_input_ML_datasets/final_modeling_input_datasets/K562_1000_expression-getmm_no-log_dose-dependent-expression.tsv.gz',
#     'expression-getmm_no-log_dose-independent-expression': '/sfs/gpfs/tardis/project/PlatigLab/users/yogi/ENCODE-RNA-Binding-Protein-Network-Modeling/analysis/6_create_RBP_to_PSI_input_ML_datasets/final_modeling_input_datasets/K562_1000_expression-getmm_no-log_dose-independent-expression.tsv.gz',
#     'expression-getmm_yes-log_dose-dependent-expression': '/sfs/gpfs/tardis/project/PlatigLab/users/yogi/ENCODE-RNA-Binding-Protein-Network-Modeling/analysis/6_create_RBP_to_PSI_input_ML_datasets/final_modeling_input_datasets/K562_1000_expression-getmm_yes-log_dose-dependent-expression.tsv.gz',
#     'expression-getmm_yes-log_dose-independent-expression': '/sfs/gpfs/tardis/project/PlatigLab/users/yogi/ENCODE-RNA-Binding-Protein-Network-Modeling/analysis/6_create_RBP_to_PSI_input_ML_datasets/final_modeling_input_datasets/K562_1000_expression-getmm_yes-log_dose-independent-expression.tsv.gz',
#     'expression-tmm_no-log_dose-dependent-expression': '/sfs/gpfs/tardis/project/PlatigLab/users/yogi/ENCODE-RNA-Binding-Protein-Network-Modeling/analysis/6_create_RBP_to_PSI_input_ML_datasets/final_modeling_input_datasets/K562_1000_expression-tmm_no-log_dose-dependent-expression.tsv.gz',
#     'expression-tmm_no-log_dose-independent-expression': '/sfs/gpfs/tardis/project/PlatigLab/users/yogi/ENCODE-RNA-Binding-Protein-Network-Modeling/analysis/6_create_RBP_to_PSI_input_ML_datasets/final_modeling_input_datasets/K562_1000_expression-tmm_no-log_dose-independent-expression.tsv.gz',
#     'expression-tmm_yes-log_dose-dependent-expression': '/sfs/gpfs/tardis/project/PlatigLab/users/yogi/ENCODE-RNA-Binding-Protein-Network-Modeling/analysis/6_create_RBP_to_PSI_input_ML_datasets/final_modeling_input_datasets/K562_1000_expression-tmm_yes-log_dose-dependent-expression.tsv.gz',
#     'expression-tmm_yes-log_dose-independent-expression': '/sfs/gpfs/tardis/project/PlatigLab/users/yogi/ENCODE-RNA-Binding-Protein-Network-Modeling/analysis/6_create_RBP_to_PSI_input_ML_datasets/final_modeling_input_datasets/K562_1000_expression-tmm_yes-log_dose-independent-expression.tsv.gz',
#     'num-peaks-only': '/sfs/gpfs/tardis/project/PlatigLab/users/yogi/ENCODE-RNA-Binding-Protein-Network-Modeling/analysis/6_create_RBP_to_PSI_input_ML_datasets/final_modeling_input_datasets/K562_1000_num-peaks-only.tsv.gz'},
#    '10000': {'binary-binding-only': '/sfs/gpfs/tardis/project/PlatigLab/users/yogi/ENCODE-RNA-Binding-Protein-Network-Modeling/analysis/6_create_RBP_to_PSI_input_ML_datasets/final_modeling_input_datasets/K562_10000_binary-binding-only.tsv.gz',
#     'expression-getmm_no-log_dose-dependent-expression': '/sfs/gpfs/tardis/project/PlatigLab/users/yogi/ENCODE-RNA-Binding-Protein-Network-Modeling/analysis/6_create_RBP_to_PSI_input_ML_datasets/final_modeling_input_datasets/K562_10000_expression-getmm_no-log_dose-dependent-expression.tsv.gz',
#     'expression-getmm_no-log_dose-independent-expression': '/sfs/gpfs/tardis/project/PlatigLab/users/yogi/ENCODE-RNA-Binding-Protein-Network-Modeling/analysis/6_create_RBP_to_PSI_input_ML_datasets/final_modeling_input_datasets/K562_10000_expression-getmm_no-log_dose-independent-expression.tsv.gz',
#     'expression-getmm_yes-log_dose-dependent-expression': '/sfs/gpfs/tardis/project/PlatigLab/users/yogi/ENCODE-RNA-Binding-Protein-Network-Modeling/analysis/6_create_RBP_to_PSI_input_ML_datasets/final_modeling_input_datasets/K562_10000_expression-getmm_yes-log_dose-dependent-expression.tsv.gz',
#     'expression-getmm_yes-log_dose-independent-expression': '/sfs/gpfs/tardis/project/PlatigLab/users/yogi/ENCODE-RNA-Binding-Protein-Network-Modeling/analysis/6_create_RBP_to_PSI_input_ML_datasets/final_modeling_input_datasets/K562_10000_expression-getmm_yes-log_dose-independent-expression.tsv.gz',
#     'expression-tmm_no-log_dose-dependent-expression': '/sfs/gpfs/tardis/project/PlatigLab/users/yogi/ENCODE-RNA-Binding-Protein-Network-Modeling/analysis/6_create_RBP_to_PSI_input_ML_datasets/final_modeling_input_datasets/K562_10000_expression-tmm_no-log_dose-dependent-expression.tsv.gz',
#     'expression-tmm_no-log_dose-independent-expression': '/sfs/gpfs/tardis/project/PlatigLab/users/yogi/ENCODE-RNA-Binding-Protein-Network-Modeling/analysis/6_create_RBP_to_PSI_input_ML_datasets/final_modeling_input_datasets/K562_10000_expression-tmm_no-log_dose-independent-expression.tsv.gz',
#     'expression-tmm_yes-log_dose-dependent-expression': '/sfs/gpfs/tardis/project/PlatigLab/users/yogi/ENCODE-RNA-Binding-Protein-Network-Modeling/analysis/6_create_RBP_to_PSI_input_ML_datasets/final_modeling_input_datasets/K562_10000_expression-tmm_yes-log_dose-dependent-expression.tsv.gz',
#     'expression-tmm_yes-log_dose-independent-expression': '/sfs/gpfs/tardis/project/PlatigLab/users/yogi/ENCODE-RNA-Binding-Protein-Network-Modeling/analysis/6_create_RBP_to_PSI_input_ML_datasets/final_modeling_input_datasets/K562_10000_expression-tmm_yes-log_dose-independent-expression.tsv.gz',
#     'num-peaks-only': '/sfs/gpfs/tardis/project/PlatigLab/users/yogi/ENCODE-RNA-Binding-Protein-Network-Modeling/analysis/6_create_RBP_to_PSI_input_ML_datasets/final_modeling_input_datasets/K562_10000_num-peaks-only.tsv.gz'},
#    '2000': {'binary-binding-only': '/sfs/gpfs/tardis/project/PlatigLab/users/yogi/ENCODE-RNA-Binding-Protein-Network-Modeling/analysis/6_create_RBP_to_PSI_input_ML_datasets/final_modeling_input_datasets/K562_2000_binary-binding-only.tsv.gz',
#     'expression-getmm_no-log_dose-dependent-expression': '/sfs/gpfs/tardis/project/PlatigLab/users/yogi/ENCODE-RNA-Binding-Protein-Network-Modeling/analysis/6_create_RBP_to_PSI_input_ML_datasets/final_modeling_input_datasets/K562_2000_expression-getmm_no-log_dose-dependent-expression.tsv.gz',
#     'expression-getmm_no-log_dose-independent-expression': '/sfs/gpfs/tardis/project/PlatigLab/users/yogi/ENCODE-RNA-Binding-Protein-Network-Modeling/analysis/6_create_RBP_to_PSI_input_ML_datasets/final_modeling_input_datasets/K562_2000_expression-getmm_no-log_dose-independent-expression.tsv.gz',
#     'expression-getmm_yes-log_dose-dependent-expression': '/sfs/gpfs/tardis/project/PlatigLab/users/yogi/ENCODE-RNA-Binding-Protein-Network-Modeling/analysis/6_create_RBP_to_PSI_input_ML_datasets/final_modeling_input_datasets/K562_2000_expression-getmm_yes-log_dose-dependent-expression.tsv.gz',
#     'expression-getmm_yes-log_dose-independent-expression': '/sfs/gpfs/tardis/project/PlatigLab/users/yogi/ENCODE-RNA-Binding-Protein-Network-Modeling/analysis/6_create_RBP_to_PSI_input_ML_datasets/final_modeling_input_datasets/K562_2000_expression-getmm_yes-log_dose-independent-expression.tsv.gz',
#     'expression-tmm_no-log_dose-dependent-expression': '/sfs/gpfs/tardis/project/PlatigLab/users/yogi/ENCODE-RNA-Binding-Protein-Network-Modeling/analysis/6_create_RBP_to_PSI_input_ML_datasets/final_modeling_input_datasets/K562_2000_expression-tmm_no-log_dose-dependent-expression.tsv.gz',
#     'expression-tmm_no-log_dose-independent-expression': '/sfs/gpfs/tardis/project/PlatigLab/users/yogi/ENCODE-RNA-Binding-Protein-Network-Modeling/analysis/6_create_RBP_to_PSI_input_ML_datasets/final_modeling_input_datasets/K562_2000_expression-tmm_no-log_dose-independent-expression.tsv.gz',
#     'expression-tmm_yes-log_dose-dependent-expression': '/sfs/gpfs/tardis/project/PlatigLab/users/yogi/ENCODE-RNA-Binding-Protein-Network-Modeling/analysis/6_create_RBP_to_PSI_input_ML_datasets/final_modeling_input_datasets/K562_2000_expression-tmm_yes-log_dose-dependent-expression.tsv.gz',
#     'expression-tmm_yes-log_dose-independent-expression': '/sfs/gpfs/tardis/project/PlatigLab/users/yogi/ENCODE-RNA-Binding-Protein-Network-Modeling/analysis/6_create_RBP_to_PSI_input_ML_datasets/final_modeling_input_datasets/K562_2000_expression-tmm_yes-log_dose-independent-expression.tsv.gz',
#     'num-peaks-only': '/sfs/gpfs/tardis/project/PlatigLab/users/yogi/ENCODE-RNA-Binding-Protein-Network-Modeling/analysis/6_create_RBP_to_PSI_input_ML_datasets/final_modeling_input_datasets/K562_2000_num-peaks-only.tsv.gz'},
#    '50': {'binary-binding-only': '/sfs/gpfs/tardis/project/PlatigLab/users/yogi/ENCODE-RNA-Binding-Protein-Network-Modeling/analysis/6_create_RBP_to_PSI_input_ML_datasets/final_modeling_input_datasets/K562_50_binary-binding-only.tsv.gz',
#     'expression-getmm_no-log_dose-dependent-expression': '/sfs/gpfs/tardis/project/PlatigLab/users/yogi/ENCODE-RNA-Binding-Protein-Network-Modeling/analysis/6_create_RBP_to_PSI_input_ML_datasets/final_modeling_input_datasets/K562_50_expression-getmm_no-log_dose-dependent-expression.tsv.gz',
#     'expression-getmm_no-log_dose-independent-expression': '/sfs/gpfs/tardis/project/PlatigLab/users/yogi/ENCODE-RNA-Binding-Protein-Network-Modeling/analysis/6_create_RBP_to_PSI_input_ML_datasets/final_modeling_input_datasets/K562_50_expression-getmm_no-log_dose-independent-expression.tsv.gz',
#     'expression-getmm_yes-log_dose-dependent-expression': '/sfs/gpfs/tardis/project/PlatigLab/users/yogi/ENCODE-RNA-Binding-Protein-Network-Modeling/analysis/6_create_RBP_to_PSI_input_ML_datasets/final_modeling_input_datasets/K562_50_expression-getmm_yes-log_dose-dependent-expression.tsv.gz',
#     'expression-getmm_yes-log_dose-independent-expression': '/sfs/gpfs/tardis/project/PlatigLab/users/yogi/ENCODE-RNA-Binding-Protein-Network-Modeling/analysis/6_create_RBP_to_PSI_input_ML_datasets/final_modeling_input_datasets/K562_50_expression-getmm_yes-log_dose-independent-expression.tsv.gz',
#     'expression-tmm_no-log_dose-dependent-expression': '/sfs/gpfs/tardis/project/PlatigLab/users/yogi/ENCODE-RNA-Binding-Protein-Network-Modeling/analysis/6_create_RBP_to_PSI_input_ML_datasets/final_modeling_input_datasets/K562_50_expression-tmm_no-log_dose-dependent-expression.tsv.gz',
#     'expression-tmm_no-log_dose-independent-expression': '/sfs/gpfs/tardis/project/PlatigLab/users/yogi/ENCODE-RNA-Binding-Protein-Network-Modeling/analysis/6_create_RBP_to_PSI_input_ML_datasets/final_modeling_input_datasets/K562_50_expression-tmm_no-log_dose-independent-expression.tsv.gz',
#     'expression-tmm_yes-log_dose-dependent-expression': '/sfs/gpfs/tardis/project/PlatigLab/users/yogi/ENCODE-RNA-Binding-Protein-Network-Modeling/analysis/6_create_RBP_to_PSI_input_ML_datasets/final_modeling_input_datasets/K562_50_expression-tmm_yes-log_dose-dependent-expression.tsv.gz',
#     'expression-tmm_yes-log_dose-independent-expression': '/sfs/gpfs/tardis/project/PlatigLab/users/yogi/ENCODE-RNA-Binding-Protein-Network-Modeling/analysis/6_create_RBP_to_PSI_input_ML_datasets/final_modeling_input_datasets/K562_50_expression-tmm_yes-log_dose-independent-expression.tsv.gz',
#     'num-peaks-only': '/sfs/gpfs/tardis/project/PlatigLab/users/yogi/ENCODE-RNA-Binding-Protein-Network-Modeling/analysis/6_create_RBP_to_PSI_input_ML_datasets/final_modeling_input_datasets/K562_50_num-peaks-only.tsv.gz'},
#    '500': {'binary-binding-only': '/sfs/gpfs/tardis/project/PlatigLab/users/yogi/ENCODE-RNA-Binding-Protein-Network-Modeling/analysis/6_create_RBP_to_PSI_input_ML_datasets/final_modeling_input_datasets/K562_500_binary-binding-only.tsv.gz',
#     'expression-getmm_no-log_dose-dependent-expression': '/sfs/gpfs/tardis/project/PlatigLab/users/yogi/ENCODE-RNA-Binding-Protein-Network-Modeling/analysis/6_create_RBP_to_PSI_input_ML_datasets/final_modeling_input_datasets/K562_500_expression-getmm_no-log_dose-dependent-expression.tsv.gz',
#     'expression-getmm_no-log_dose-independent-expression': '/sfs/gpfs/tardis/project/PlatigLab/users/yogi/ENCODE-RNA-Binding-Protein-Network-Modeling/analysis/6_create_RBP_to_PSI_input_ML_datasets/final_modeling_input_datasets/K562_500_expression-getmm_no-log_dose-independent-expression.tsv.gz',
#     'expression-getmm_yes-log_dose-dependent-expression': '/sfs/gpfs/tardis/project/PlatigLab/users/yogi/ENCODE-RNA-Binding-Protein-Network-Modeling/analysis/6_create_RBP_to_PSI_input_ML_datasets/final_modeling_input_datasets/K562_500_expression-getmm_yes-log_dose-dependent-expression.tsv.gz',
#     'expression-getmm_yes-log_dose-independent-expression': '/sfs/gpfs/tardis/project/PlatigLab/users/yogi/ENCODE-RNA-Binding-Protein-Network-Modeling/analysis/6_create_RBP_to_PSI_input_ML_datasets/final_modeling_input_datasets/K562_500_expression-getmm_yes-log_dose-independent-expression.tsv.gz',
#     'expression-tmm_no-log_dose-dependent-expression': '/sfs/gpfs/tardis/project/PlatigLab/users/yogi/ENCODE-RNA-Binding-Protein-Network-Modeling/analysis/6_create_RBP_to_PSI_input_ML_datasets/final_modeling_input_datasets/K562_500_expression-tmm_no-log_dose-dependent-expression.tsv.gz',
#     'expression-tmm_no-log_dose-independent-expression': '/sfs/gpfs/tardis/project/PlatigLab/users/yogi/ENCODE-RNA-Binding-Protein-Network-Modeling/analysis/6_create_RBP_to_PSI_input_ML_datasets/final_modeling_input_datasets/K562_500_expression-tmm_no-log_dose-independent-expression.tsv.gz',
#     'expression-tmm_yes-log_dose-dependent-expression': '/sfs/gpfs/tardis/project/PlatigLab/users/yogi/ENCODE-RNA-Binding-Protein-Network-Modeling/analysis/6_create_RBP_to_PSI_input_ML_datasets/final_modeling_input_datasets/K562_500_expression-tmm_yes-log_dose-dependent-expression.tsv.gz',
#     'expression-tmm_yes-log_dose-independent-expression': '/sfs/gpfs/tardis/project/PlatigLab/users/yogi/ENCODE-RNA-Binding-Protein-Network-Modeling/analysis/6_create_RBP_to_PSI_input_ML_datasets/final_modeling_input_datasets/K562_500_expression-tmm_yes-log_dose-independent-expression.tsv.gz',
#     'num-peaks-only': '/sfs/gpfs/tardis/project/PlatigLab/users/yogi/ENCODE-RNA-Binding-Protein-Network-Modeling/analysis/6_create_RBP_to_PSI_input_ML_datasets/final_modeling_input_datasets/K562_500_num-peaks-only.tsv.gz'},
#    '5000': {'binary-binding-only': '/sfs/gpfs/tardis/project/PlatigLab/users/yogi/ENCODE-RNA-Binding-Protein-Network-Modeling/analysis/6_create_RBP_to_PSI_input_ML_datasets/final_modeling_input_datasets/K562_5000_binary-binding-only.tsv.gz',
#     'expression-getmm_no-log_dose-dependent-expression': '/sfs/gpfs/tardis/project/PlatigLab/users/yogi/ENCODE-RNA-Binding-Protein-Network-Modeling/analysis/6_create_RBP_to_PSI_input_ML_datasets/final_modeling_input_datasets/K562_5000_expression-getmm_no-log_dose-dependent-expression.tsv.gz',
#     'expression-getmm_no-log_dose-independent-expression': '/sfs/gpfs/tardis/project/PlatigLab/users/yogi/ENCODE-RNA-Binding-Protein-Network-Modeling/analysis/6_create_RBP_to_PSI_input_ML_datasets/final_modeling_input_datasets/K562_5000_expression-getmm_no-log_dose-independent-expression.tsv.gz',
#     'expression-getmm_yes-log_dose-dependent-expression': '/sfs/gpfs/tardis/project/PlatigLab/users/yogi/ENCODE-RNA-Binding-Protein-Network-Modeling/analysis/6_create_RBP_to_PSI_input_ML_datasets/final_modeling_input_datasets/K562_5000_expression-getmm_yes-log_dose-dependent-expression.tsv.gz',
#     'expression-getmm_yes-log_dose-independent-expression': '/sfs/gpfs/tardis/project/PlatigLab/users/yogi/ENCODE-RNA-Binding-Protein-Network-Modeling/analysis/6_create_RBP_to_PSI_input_ML_datasets/final_modeling_input_datasets/K562_5000_expression-getmm_yes-log_dose-independent-expression.tsv.gz',
#     'expression-tmm_no-log_dose-dependent-expression': '/sfs/gpfs/tardis/project/PlatigLab/users/yogi/ENCODE-RNA-Binding-Protein-Network-Modeling/analysis/6_create_RBP_to_PSI_input_ML_datasets/final_modeling_input_datasets/K562_5000_expression-tmm_no-log_dose-dependent-expression.tsv.gz',
#     'expression-tmm_no-log_dose-independent-expression': '/sfs/gpfs/tardis/project/PlatigLab/users/yogi/ENCODE-RNA-Binding-Protein-Network-Modeling/analysis/6_create_RBP_to_PSI_input_ML_datasets/final_modeling_input_datasets/K562_5000_expression-tmm_no-log_dose-independent-expression.tsv.gz',
#     'expression-tmm_yes-log_dose-dependent-expression': '/sfs/gpfs/tardis/project/PlatigLab/users/yogi/ENCODE-RNA-Binding-Protein-Network-Modeling/analysis/6_create_RBP_to_PSI_input_ML_datasets/final_modeling_input_datasets/K562_5000_expression-tmm_yes-log_dose-dependent-expression.tsv.gz',
#     'expression-tmm_yes-log_dose-independent-expression': '/sfs/gpfs/tardis/project/PlatigLab/users/yogi/ENCODE-RNA-Binding-Protein-Network-Modeling/analysis/6_create_RBP_to_PSI_input_ML_datasets/final_modeling_input_datasets/K562_5000_expression-tmm_yes-log_dose-independent-expression.tsv.gz',
#     'num-peaks-only': '/sfs/gpfs/tardis/project/PlatigLab/users/yogi/ENCODE-RNA-Binding-Protein-Network-Modeling/analysis/6_create_RBP_to_PSI_input_ML_datasets/final_modeling_input_datasets/K562_5000_num-peaks-only.tsv.gz'}}},
#  'Peak Distance Thresholds': ['100',
#   '1000',
#   '10000',
#   '2000',
#   '50',
#   '500',
#   '5000']}

# %%
import pandas as pd
import matplotlib.pyplot as plt

for column in ["Total Read Counts", "Target_PSI"]: 
    
    for cell_line in cell_lines: 
        for threshold in thresholds: 

            file = glob.glob("../final_modeling_input_datasets/{}_{}_binary*.tsv.gz".format(cell_line, threshold))

            assert len(file)==1
            
            plt.figure(dpi=200)
            
            plt.title("{} {} {}".format(column, cell_line, threshold))

            plotting_lst = pd.read_csv(file[0], sep="\t", compression="gzip", usecols=[column])[column].to_list()
            pd.Series(plotting_lst).describe()
            
            plt.hist(plotting_lst, bins=100)
            
            plt.show()
# Out:
# Text(0.5, 1.0, 'Target_PSI HepG2 100')
# ---------------------------------------------------------------------------
# ParserError                               Traceback (most recent call last)
# Cell In[7], line 17
#      13 plt.figure(dpi=200)
#      15 plt.title("{} {} {}".format(column, cell_line, threshold))
# ---> 17 plotting_lst = pd.read_csv(file[0], sep="\t", compression="gzip", usecols=[column])[column].to_list()
#      18 pd.Series(plotting_lst).describe()
#      20 plt.hist(plotting_lst, bins=100)
#
# File ~/.local/lib/python3.11/site-packages/pandas/io/parsers/readers.py:1026, in read_csv(filepath_or_buffer, sep, delimiter, header, names, index_col, usecols, dtype, engine, converters, true_values, false_values, skipinitialspace, skiprows, skipfooter, nrows, na_values, keep_default_na, na_filter, verbose, skip_blank_lines, parse_dates, infer_datetime_format, keep_date_col, date_parser, date_format, dayfirst, cache_dates, iterator, chunksize, compression, thousands, decimal, lineterminator, quotechar, quoting, doublequote, escapechar, comment, encoding, encoding_errors, dialect, on_bad_lines, delim_whitespace, low_memory, memory_map, float_precision, storage_options, dtype_backend)
#    1013 kwds_defaults = _refine_defaults_read(
#    1014     dialect,
#    1015     delimiter,
#    (...)
#    1022     dtype_backend=dtype_backend,
#    1023 )
#    1024 kwds.update(kwds_defaults)
# -> 1026 return _read(filepath_or_buffer, kwds)
#
# File ~/.local/lib/python3.11/site-packages/pandas/io/parsers/readers.py:626, in _read(filepath_or_buffer, kwds)
#     623     return parser
#     625 with parser:
# --> 626     return parser.read(nrows)
#
# File ~/.local/lib/python3.11/site-packages/pandas/io/parsers/readers.py:1923, in TextFileReader.read(self, nrows)
#    1916 nrows = validate_integer("nrows", nrows)
#    1917 try:
#    1918     # error: "ParserBase" has no attribute "read"
#    1919     (
#    1920         index,
#    1921         columns,
#    1922         col_dict,
# -> 1923     ) = self._engine.read(  # type: ignore[attr-defined]
#    1924         nrows
#    1925     )
#    1926 except Exception:
#    1927     self.close()
#
# File ~/.local/lib/python3.11/site-packages/pandas/io/parsers/c_parser_wrapper.py:234, in CParserWrapper.read(self, nrows)
#     232 try:
#     233     if self.low_memory:
# --> 234         chunks = self._reader.read_low_memory(nrows)
#     235         # destructive to chunks
#     236         data = _concatenate_chunks(chunks)
#
# File parsers.pyx:838, in pandas._libs.parsers.TextReader.read_low_memory()
#
# File parsers.pyx:905, in pandas._libs.parsers.TextReader._read_rows()
#
# File parsers.pyx:874, in pandas._libs.parsers.TextReader._tokenize_rows()
#
# File parsers.pyx:891, in pandas._libs.parsers.TextReader._check_tokenize_status()
#
# File parsers.pyx:2061, in pandas._libs.parsers.raise_parser_error()
#
# ParserError: Error tokenizing data. C error: Calling read(nbytes) on source failed. Try engine='python'.
