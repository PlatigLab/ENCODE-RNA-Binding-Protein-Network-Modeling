# %%
from IPython.core.interactiveshell import InteractiveShell
InteractiveShell.ast_node_interactivity = "all"

# %load_ext autoreload 
# %autoreload 2

import pandas as pd
pd.set_option('display.max_rows', 1000000)
pd.set_option('display.max_columns', 1000000)
pd.set_option('display.max_colwidth', 10000000)

import importlib
parameter_analyzer = getattr(
    importlib.import_module("dataset_and_model_parameter_chooser"), 
    "DatasetAndModelParameterAnalyzer"
)

# %%
analyzer = parameter_analyzer()
# Out:
# 2025-02-24 17:51:26.430 | INFO     | dataset_and_model_parameter_chooser:retrieve_wandb_summary_tables:39 - FROM CACHE: Retrieved WandB summary tables
# 2025-02-24 17:51:26.430 | INFO     | dataset_and_model_parameter_chooser:run_summary_table_assertions:80 - Running assertions on summary tables
# 2025-02-24 17:51:26.433 | SUCCESS  | dataset_and_model_parameter_chooser:run_summary_table_assertions:96 - All assertions passed

# %%
for type in analyzer.sweep_results: 
    analyzer.sweep_results[type].head()
# Out:
#      run_id           run_name     state  \
# 0  1o95bl4u  glamorous-sweep-6  finished
# 1  5j9ipstu      brisk-sweep-1  finished
# 2  9kh7spri      sandy-sweep-4  finished
# 3  ainnw5al     iconic-sweep-3  finished
# 4  nhhpps7z      clean-sweep-7  finished
#
#                               sweep_name  sweep_id    model.name  \
# 0  ayans_model_params_yogi_dataset_sweep  11gitmno  XGBRegressor
# 1  ayans_model_params_yogi_dataset_sweep  11gitmno  XGBRegressor
# 2  ayans_model_params_yogi_dataset_sweep  11gitmno  XGBRegressor
# 3  ayans_model_params_yogi_dataset_sweep  11gitmno  XGBRegressor
# 4  ayans_model_params_yogi_dataset_sweep  11gitmno  XGBRegressor
#
#    dataset.name  model.n_jobs  training.seed  model.max_depth  \
# 0  RBPSEDataset            -1             42                7
# 1  RBPSEDataset            -1             42                7
# 2  RBPSEDataset            -1             42                7
# 3  RBPSEDataset            -1             42                7
# 4  RBPSEDataset            -1             42                7
#
#    model.reg_alpha  model.subsample dataset.cell_line    model.eval_metric  \
# 0              0.3                1              K562  ['rmse', 'logloss']
# 1              0.3                1              K562  ['rmse', 'logloss']
# 2              0.3                1              K562  ['rmse', 'logloss']
# 3              0.3                1              K562  ['rmse', 'logloss']
# 4              0.3                1              K562  ['rmse', 'logloss']
#
#    model.n_estimators  training.criterion  model.learning_rate  \
# 0               20000  mean_squared_error                  0.1
# 1               20000  mean_squared_error                  0.1
# 2               20000  mean_squared_error                  0.1
# 3               20000  mean_squared_error                  0.1
# 4               20000  mean_squared_error                  0.1
#
#    training.batch_size  training.wandb.track dataset.target_fields  \
# 0                 1024                  True        ['target_psi']
# 1                 1024                  True        ['target_psi']
# 2                 1024                  True        ['target_psi']
# 3                 1024                  True        ['target_psi']
# 4                 1024                  True        ['target_psi']
#
#   training.wandb.entity  dataset.min_read_count training.profile.plots  \
# 0             platiglab                     320                     []
# 1             platiglab                       0                     []
# 2             platiglab                      80                     []
# 3             platiglab                      40                     []
# 4             platiglab                       0                     []
#
#         training.wandb.project  model.enable_categorical  \
# 0  yogi-dataset-sweep-feb-2025                     False
# 1  yogi-dataset-sweep-feb-2025                     False
# 2  yogi-dataset-sweep-feb-2025                     False
# 3  yogi-dataset-sweep-feb-2025                     False
# 4  yogi-dataset-sweep-feb-2025                     False
#
#                       training.profile.metrics  training.wandb.save_code  \
# 0  ['r2_score', 'mean_absolute_error', 'rmse']                     False
# 1  ['r2_score', 'mean_absolute_error', 'rmse']                     False
# 2  ['r2_score', 'mean_absolute_error', 'rmse']                     False
# 3  ['r2_score', 'mean_absolute_error', 'rmse']                     False
# 4  ['r2_score', 'mean_absolute_error', 'rmse']                     False
#
#   dataset.three_exon_combos  training.wandb.save_model  \
# 0                       all                      False
# 1                       all                      False
# 2                       all                      False
# 3                       all                      False
# 4                       all                      False
#
#    training.wandb.save_plots training.data_split.method  \
# 0                      False                   set_defs
# 1                      False                   set_defs
# 2                      False                   set_defs
# 3                      False                   set_defs
# 4                      False                   set_defs
#
#    model.early_stopping_rounds                 training.data_split.test_set  \
# 0                          100  ['chr2', 'chr8', 'chr12', 'chr16', 'chr20']
# 1                          100  ['chr2', 'chr8', 'chr12', 'chr16', 'chr20']
# 2                          100  ['chr2', 'chr8', 'chr12', 'chr16', 'chr20']
# 3                          100  ['chr2', 'chr8', 'chr12', 'chr16', 'chr20']
# 4                          100  ['chr2', 'chr8', 'chr12', 'chr16', 'chr20']
#
#                                                                     training.data_split.train_set  \
# 0  ['chr1', 'chr3', 'chr5', 'chr7', 'chr9', 'chr11', 'chr13', 'chr15', 'chr17', 'chr19', 'chr21']
# 1  ['chr1', 'chr3', 'chr5', 'chr7', 'chr9', 'chr11', 'chr13', 'chr15', 'chr17', 'chr19', 'chr21']
# 2  ['chr1', 'chr3', 'chr5', 'chr7', 'chr9', 'chr11', 'chr13', 'chr15', 'chr17', 'chr19', 'chr21']
# 3  ['chr1', 'chr3', 'chr5', 'chr7', 'chr9', 'chr11', 'chr13', 'chr15', 'chr17', 'chr19', 'chr21']
# 4  ['chr1', 'chr3', 'chr5', 'chr7', 'chr9', 'chr11', 'chr13', 'chr15', 'chr17', 'chr19', 'chr21']
#
#    training.wandb.save_artifacts  \
# 0                          False
# 1                          False
# 2                          False
# 3                          False
# 4                          False
#
#                        training.data_split.validate_set  \
# 0  ['chr4', 'chr6', 'chr10', 'chr14', 'chr18', 'chr22']
# 1  ['chr4', 'chr6', 'chr10', 'chr14', 'chr18', 'chr22']
# 2  ['chr4', 'chr6', 'chr10', 'chr14', 'chr18', 'chr22']
# 3  ['chr4', 'chr6', 'chr10', 'chr14', 'chr18', 'chr22']
# 4  ['chr4', 'chr6', 'chr10', 'chr14', 'chr18', 'chr22']
#
#    dataset.features.binding_matrix.window  \
# 0                                      50
# 1                                      50
# 2                                      50
# 3                                      50
# 4                                     100
#
#    dataset.features.binding_matrix.exp_log  \
# 0                                     True
# 1                                     True
# 2                                     True
# 3                                     True
# 4                                     True
#
#    dataset.features.binding_matrix.flatten  \
# 0                                    False
# 1                                    False
# 2                                    False
# 3                                    False
# 4                                    False
#
#   dataset.features.binding_matrix.exp_norm  \
# 0                                    getmm
# 1                                    getmm
# 2                                    getmm
# 3                                    getmm
# 4                                    getmm
#
#   dataset.features.binding_matrix.binding_format  runtime.avg_nodes_per_tree  \
# 0                                         binary                   69.500000
# 1                                         binary                   81.634328
# 2                                         binary                   76.023077
# 3                                         binary                   76.436090
# 4                                         binary                   82.549618
#
#    test_loss  test_mean_absolute_error  test_r2_score  test_rmse  train_loss  \
# 0   0.000166                    0.1645         0.2155     0.2772    0.000047
# 1   0.000055                    0.2571         0.1746     0.3328    0.000021
# 2   0.000075                    0.2013         0.1953     0.3001    0.000026
# 3   0.000064                    0.2202         0.1897     0.3120    0.000023
# 4   0.000054                    0.2590         0.1700     0.3339    0.000021
#
#    train_mean_absolute_error  train_r2_score  train_rmse  val_loss  \
# 0                     0.1331          0.3402      0.2330  0.000181
# 1                     0.2372          0.2062      0.3124  0.000069
# 2                     0.1799          0.2428      0.2745  0.000092
# 3                     0.1989          0.2338      0.2877  0.000080
# 4                     0.2395          0.2015      0.3142  0.000068
#
#    val_mean_absolute_error  val_r2_score  val_rmse
# 0                   0.1529        0.2067    0.2604
# 1                   0.2484        0.1676    0.3229
# 2                   0.1920        0.1891    0.2883
# 3                   0.2103        0.1848    0.3003
# 4                   0.2506        0.1626    0.3244

# %%
analyzer.load_aggreated_data_stats()

# %%
analyzer.plot_r2_distributions()
# Out:
# /sfs/gpfs/tardis/project/PlatigLab/users/yogi/ENCODE-RNA-Binding-Protein-Network-Modeling/analysis/4_choose_dataset_and_model_parameters/code/dataset_and_model_parameter_chooser.py:204: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `x` variable to `hue` and set `legend=False` for the same effect.
#
#   sns.swarmplot(x='dataset.cell_line', y='val_r2_score', data=data, palette=['lightblue', 'lightcoral'], linewidth=1, edgecolor='black')

# %%
analyzer.plot_r2_per_covariate(type='dataset')
