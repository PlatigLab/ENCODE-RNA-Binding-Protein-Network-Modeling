# %%
# Load in packages
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import polars as pl
_=pl.Config.set_tbl_cols(100000)
_=pl.Config.set_tbl_rows(10000)
_=pl.Config.set_tbl_width_chars(10000)
_=pl.Config.set_fmt_str_lengths(10000)

from sklearn.model_selection import train_test_split
from sklearn.linear_model import LogisticRegression
from sklearn.metrics import roc_curve, auc, precision_recall_curve, average_precision_score
import matplotlib.pyplot as plt

# %%
# Function to get path

from pathlib import Path

def get_path(cell_line: str, path_file: str = "data_path.txt") -> str:
    """
    Reads a base directory path from a text file and returns the full path
    to the cell line data directory.

    Args:
        cell_line (str): The name of the cell line (e.g. "K562" or "HepG2").
        path_file (str): Path to the text file containing the base directory path.

    Returns:
        str: Full path to the data file for the given cell line.
    """
    # Read base path from file
    base_path = Path(path_file).read_text().strip()
    
    # Build full path
    full_path = Path(base_path) / f"{cell_line}_all-data.feather"
    
    return str(full_path)

# %% [markdown]
# ## HepG2

# %%
# Read in HepG2 table
HepG2_big_data_path = get_path("HepG2")
HepG2_data = pl.read_ipc(HepG2_big_data_path)
# Out:
# Could not memory_map compressed IPC file, defaulting to normal read. Toggle off 'memory_map' to silence this warning.

# %%
# Extract a list of all RBPs from the binding columns

# Get all column names that contain "binding"
binding_cols = [col for col in HepG2_data.columns if 'binding' in col]

# Extract protein names (everything before the first underscore)
protein_names = list(set([col.split('_')[0] for col in binding_cols]))

# Make a list of positions

positions = [1, 2, 3, 4, 5, 6]

# %%
# Loop through each feature

# Initialize results dataframe
results_list = []

# Run through the loop for each protein at each position
for rbp in protein_names:
    for position in positions:
    
        # print(f"Processing: {rbp}")
        # print(f"Position: {position}")
    
        columns_to_keep = [
            "rMATS Event ID",
            f"{rbp}_{position}_binding",
            "FDR",
            "DeltaPSI",
            f"{rbp}_{position}_shap",
            "Sample Name"
        ]
    
        # Drop unnecessary columns
        rbp_data = HepG2_data.select(columns_to_keep)
    
        rbp_data_filtered = (
            rbp_data
            .filter(
                (pl.col("Sample Name").str.contains("KD", literal=True)) &
                (pl.col(f"{rbp}_{position}_binding") == 1)
            )
            .unique(subset=["rMATS Event ID"])
        )
        
        # Convert to pandas
        rbp_df = rbp_data_filtered.to_pandas()
    
        # Print to check
        # print(rbp_df)
        
        # Add a new column based on significance (significant if FDR <= 0.05 and abs dPSI >= 0.1
        rbp_df['Significant'] = np.where(
            (rbp_df['FDR'] <= 0.05) & (rbp_df['DeltaPSI'].abs() >= 0.1),
            1,
            0
        )
        
        # Count total events and significant events
        total_events = len(rbp_df)
        num_significant = rbp_df['Significant'].sum()
        
        # Skip if all events are not significant (all zeros in Significant column)
        if num_significant == 0:
            print(f"Skipping {rbp} at position {position}: No significant events")
            continue
    
        # Make training data
        smaller_df = rbp_df[[f'{rbp}_{position}_shap', 'Significant', 'rMATS Event ID']].copy()
        
        smaller_df['absolute_shap'] = smaller_df[f'{rbp}_{position}_shap'].abs()
        
        smaller_df = smaller_df.rename(columns={'rMATS Event ID': 'Event_ID'})
        
        smaller_df = smaller_df[['absolute_shap', 'Significant', 'Event_ID']]
    
    
        # Training logistic regression model
        
        # Prepare data
        X = smaller_df[['absolute_shap']].values  # Features
        y = smaller_df['Significant'].values      # Target
        
        # Train a classifier on all data
        classifier = LogisticRegression()
        classifier.fit(X, y)
        
        # Get predicted probabilities for the same data
        y_pred_proba = classifier.predict_proba(X)[:, 1]  # Probability of class 1
    
        # Calculate ROC curve
        fpr, tpr, thresholds_roc = roc_curve(y, y_pred_proba)
        roc_auc = auc(fpr, tpr)
    
        # Calculate PRC
        precision, recall, thresholds_pr = precision_recall_curve(y, y_pred_proba)
        avg_precision = average_precision_score(y, y_pred_proba)
        
        # Store the results with event counts
        results_list.append({
            'feature': f'{rbp}_{position}',
            'AUROC': roc_auc,
            'AUPRC': avg_precision,
            'total_events': total_events,
            'num_significant': num_significant
        })
        
# Create final results dataframe
results_df = pd.DataFrame(results_list)
print("\nFinal Results:")
print(results_df)
# Out:
# Skipping STAU2 at position 2: No significant events
# Skipping FUBP3 at position 2: No significant events
# Skipping POLR2G at position 1: No significant events
# Skipping POLR2G at position 2: No significant events
# Skipping POLR2G at position 3: No significant events
# Skipping POLR2G at position 4: No significant events
# Skipping POLR2G at position 6: No significant events
# Skipping TBRG4 at position 1: No significant events
# Skipping TBRG4 at position 2: No significant events
# Skipping TBRG4 at position 3: No significant events
# Skipping TBRG4 at position 4: No significant events
# Skipping TBRG4 at position 5: No significant events
# Skipping TBRG4 at position 6: No significant events
# Skipping DDX52 at position 1: No significant events
# Skipping DDX52 at position 4: No significant events
# Skipping DDX52 at position 6: No significant events
# Skipping SAFB at position 1: No significant events
# Skipping SAFB at position 4: No significant events
# Skipping SAFB at position 5: No significant events
# Skipping SAFB at position 6: No significant events
# Skipping BCCIP at position 4: No significant events
# Skipping BCCIP at position 6: No significant events
# Skipping TAF15 at position 6: No significant events
# Skipping SSB at position 2: No significant events
# Skipping HNRNPA1 at position 1: No significant events
# Skipping HNRNPA1 at position 2: No significant events
# Skipping HNRNPA1 at position 3: No significant events
# Skipping HNRNPA1 at position 4: No significant events
# Skipping HNRNPA1 at position 6: No significant events
# Skipping DHX30 at position 3: No significant events
# Skipping DHX30 at position 4: No significant events
# Skipping DHX30 at position 5: No significant events
# Skipping DHX30 at position 6: No significant events
# Skipping SMNDC1 at position 6: No significant events
# Skipping NSUN2 at position 4: No significant events
# Skipping NSUN2 at position 6: No significant events
# Skipping XRCC6 at position 2: No significant events
# Skipping XRCC6 at position 4: No significant events
# Skipping XRCC6 at position 5: No significant events
# Skipping XRCC6 at position 6: No significant events
# Skipping TROVE2 at position 1: No significant events
# Skipping TROVE2 at position 2: No significant events
# Skipping TROVE2 at position 3: No significant events
# Skipping WDR43 at position 2: No significant events
# Skipping SFPQ at position 5: No significant events
# Skipping HNRNPU at position 2: No significant events
# Skipping HNRNPU at position 6: No significant events
# Skipping MATR3 at position 4: No significant events
# Skipping MATR3 at position 6: No significant events
# Skipping UTP18 at position 1: No significant events
# Skipping UTP18 at position 4: No significant events
# Skipping DDX6 at position 2: No significant events
# Skipping HNRNPUL1 at position 4: No significant events
# Skipping HNRNPUL1 at position 5: No significant events
# Skipping HNRNPUL1 at position 6: No significant events
#
# Final Results:
#      feature     AUROC     AUPRC  total_events  num_significant
# 0    PTBP1_1  0.351140  0.015882          2162               42
# 1    PTBP1_2  0.375583  0.005539          2978               20
# 2    PTBP1_3  0.547139  0.030630          4776              138
# 3    PTBP1_4  0.620790  0.036252          4058              108
# 4    PTBP1_5  0.256804  0.018205          2160               58
# ..       ...       ...       ...           ...              ...
# 570  FKBP4_2  0.558707  0.020074          3800               65
# 571  FKBP4_3  0.487147  0.008772           643                5
# 572  FKBP4_4  0.500000  0.018519           972               18
# 573  FKBP4_5  0.500000  0.023256           172                4
# 574  FKBP4_6  0.500000  0.011719           256                3
#
# [575 rows x 5 columns]

# %%
# Save and sort results
results_df.to_csv('v2_HepG2_auroc_auprc_results.csv', index=False)

results_df = results_df.sort_values(by=['AUROC', 'AUPRC'], ascending=[False, False])

results_df2 = results_df.sort_values(by=['AUPRC', 'AUROC'], ascending=[False, False])

# %%
# Plot highest values 

# Best ROCs: DDX55_3, TIA1_1, DDX55_1, AGGF1_4, SFPQ_4
# Best PRCS: AGGF1_4, UPF1_3, HNRNPA1_5, XRN2_6, WDR43_3

# %%
def plot_best_curves(features, data, plot=True, save_dir=None):
    """
    Train logistic regression models for a list of features and evaluate their performance.
    
    Parameters:
    -----------
    features : list
        List of feature names (e.g., ["DDX55_3", "TIA1_1", "AGGF1_4"])
    data : polars.DataFrame
        The main polars dataframe containing all the data
    plot : bool, default=True
        Whether to display plots for each 
    save_dir : str, optional
        Directory to save plots. If None, plots are not saved to files.
        Example: save_dir='plots' or save_dir='results/figures'
    
    Returns:
    --------
    results_df : pandas.DataFrame
        DataFrame with columns 'feature', 'AUROC', and 'AUPRC'
    """
    import polars as pl
    import pandas as pd
    import numpy as np
    import matplotlib.pyplot as plt
    from sklearn.linear_model import LogisticRegression
    from sklearn.metrics import roc_curve, auc, precision_recall_curve, average_precision_score
    import os

    # Create save directory if specified
    if save_dir:
        os.makedirs(save_dir, exist_ok=True)
    
    # Initialize results list
    results_list = []
    
    # Run through the loop for each feature
    for each in features:
        # print(f"Processing: {each}")
        
        columns_to_keep = [
            "rMATS Event ID",
            f"{each}_binding",
            "FDR",
            "DeltaPSI",
            f"{each}_shap",
            "Sample Name"
        ]
        
        # Drop unnecessary columns
        rbp_data = data.select(columns_to_keep)
        
        rbp_data_filtered = (
            rbp_data
            .filter(
                (pl.col("Sample Name").str.contains("KD", literal=True)) &
                (pl.col(f"{each}_binding") == 1)
            )
            .unique(subset=["rMATS Event ID"])
        )
        
        # Convert to pandas
        rbp_df = rbp_data_filtered.to_pandas()
        
        # Add a new column based on significance (significant if FDR <= 0.05 and abs dPSI >= 0.1)
        rbp_df['Significant'] = np.where(
            (rbp_df['FDR'] <= 0.05) & (rbp_df['DeltaPSI'].abs() >= 0.1),
            1,
            0
        )

        # Count total events and significant events
        total_events = len(rbp_df)
        num_significant = rbp_df['Significant'].sum()
        
        # Skip if all events are not significant (all zeros in Significant column)
        if rbp_df['Significant'].sum() == 0:
            print(f"Skipping {each}: No significant events")
            continue
        
        # Make training data
        smaller_df = rbp_df[[f'{each}_shap', 'Significant', 'rMATS Event ID']].copy()
        
        smaller_df['absolute_shap'] = smaller_df[f'{each}_shap'].abs()
        
        smaller_df = smaller_df.rename(columns={'rMATS Event ID': 'Event_ID'})
        
        smaller_df = smaller_df[['absolute_shap', 'Significant', 'Event_ID']]
        
        # Print to check
        # print(smaller_df)
        
        if plot:
            # Plot training data
            plt.figure(figsize=(10, 6))
            plt.scatter(smaller_df['absolute_shap'], smaller_df['Significant'], alpha=0.5)
            plt.xlabel('Absolute SHAP', fontsize=14, labelpad=10)
            plt.ylabel('Significant', fontsize=14, labelpad=10)
            plt.title(f'Absolute SHAP vs Significance Status for {each}', fontsize=16, pad=15)
            plt.yticks([0, 1])
            # Add text box with event counts
            textstr = f'Total Events = {total_events}\nSignificant Events = {num_significant}'
            plt.text(0.95, 0.95, textstr, transform=plt.gca().transAxes, 
                    fontsize=12, verticalalignment='top', horizontalalignment='right',
                    bbox=dict(boxstyle='round', facecolor='white', alpha=0.5))

            if save_dir:
                plt.savefig(f'{save_dir}/{each}_scatter.png', dpi=300, bbox_inches='tight')
            plt.show()
        
        # Training logistic regression model
        
        # Prepare data
        X = smaller_df[['absolute_shap']].values  # Features
        y = smaller_df['Significant'].values      # Target
        
        # Train a classifier on all data
        classifier = LogisticRegression()
        classifier.fit(X, y)
        
        # Get predicted probabilities for the same data
        y_pred_proba = classifier.predict_proba(X)[:, 1]  # Probability of class 1
        
        # Calculate ROC curve
        fpr, tpr, thresholds_roc = roc_curve(y, y_pred_proba)
        roc_auc = auc(fpr, tpr)
        
        # Calculate PRC
        precision, recall, thresholds_pr = precision_recall_curve(y, y_pred_proba)
        avg_precision = average_precision_score(y, y_pred_proba)
        
        if plot:
            # Plot ROC Curve
            plt.figure(figsize=(12, 5))
            
            plt.subplot(1, 2, 1)
            plt.plot(fpr, tpr, color='darkorange', lw=2, label=f'ROC curve (AUC = {roc_auc:.2f})')
            plt.plot([0, 1], [0, 1], color='navy', lw=2, linestyle='--', label='Random Classifier')
            # Add invisible plot for event counts in legend
            plt.plot([], [], ' ', label=f'Total Events = {total_events}')
            plt.plot([], [], ' ', label=f'Significant Events = {num_significant}')
            plt.xlim([0.0, 1.0])
            plt.ylim([0.0, 1.05])
            plt.xlabel('False Positive Rate', fontsize=14, labelpad=10)
            plt.ylabel('True Positive Rate', fontsize=14, labelpad=10)
            plt.title(f'ROC Curve for {each}', fontsize=16, pad=15)
            plt.legend(loc="lower right", fontsize=11)
            
            # Plot Precision-Recall Curve
            plt.subplot(1, 2, 2)
            plt.plot(recall, precision, color='blue', lw=2, label=f'PR curve (AP = {avg_precision:.2f})')
            # Add invisible plot for event counts in legend
            plt.plot([], [], ' ', label=f'Total Events = {total_events}')
            plt.plot([], [], ' ', label=f'Significant Events = {num_significant}')
            plt.xlim([0.0, 1.0])
            plt.ylim([0.0, 1.05])
            plt.xlabel('Recall', fontsize=14, labelpad=10)
            plt.ylabel('Precision', fontsize=14, labelpad=10)
            plt.title(f'Precision-Recall Curve for {each}', fontsize=16, pad=15)
            plt.legend(loc="lower right", fontsize=11)
            
            plt.tight_layout()
            
            if save_dir:
                plt.savefig(f'{save_dir}/{each}_roc_prc.png', dpi=300, bbox_inches='tight')
            plt.show()
        
        # Store the results
        results_list.append({
            'feature': f'{each}',
            'AUROC': roc_auc,
            'AUPRC': avg_precision,
            'total_events': total_events,
            'num_significant': num_significant
        })
    
    # Create final results dataframe
    results_df = pd.DataFrame(results_list)
    print("\nFinal Results:")
    print(results_df)
    
    return results_df

# %%
# Best ROCs
features = ["DDX55_3", "TIA1_1", "DDX55_1", "AGGF1_4", "SFPQ_4"]
# results_df = plot_best_curves(features, HepG2_data, plot=True, save_dir='HepG2_ROC_plots')

# %%
# Best PRCs
features = ["AGGF1_4", "UPF1_3", "HNRNPA1_5", "XRN2_6", "WDR43_3"]
# results_df = plot_best_curves(features, HepG2_data, plot=True, save_dir='HepG2_PRC_plots')

# %% [markdown]
# ## K562

# %%
# Read in HepG2 table
K562_big_data_path = get_path("K562")
K562_data = pl.read_ipc(K562_big_data_path)
# Out:
# Could not memory_map compressed IPC file, defaulting to normal read. Toggle off 'memory_map' to silence this warning.

# %%
# Extract a list of all RBPs from the binding columns

# Get all column names that contain "binding"
binding_cols = [col for col in K562_data.columns if 'binding' in col]

# Extract protein names (everything before the first underscore)
protein_names = list(set([col.split('_')[0] for col in binding_cols]))

# Make a list of positions

positions = [1, 2, 3, 4, 5, 6]

# %%
## Loop through each feature

# Initialize results dataframe
results_list = []

# Run through the loop for each protein at each position
for rbp in protein_names:
    for position in positions:
    
        # print(f"Processing: {rbp}")
        # print(f"Position: {position}")
    
        columns_to_keep = [
            "rMATS Event ID",
            f"{rbp}_{position}_binding",
            "FDR",
            "DeltaPSI",
            f"{rbp}_{position}_shap",
            "Sample Name"
        ]
    
        # Drop unnecessary columns
        rbp_data = K562_data.select(columns_to_keep)
    
        rbp_data_filtered = (
            rbp_data
            .filter(
                (pl.col("Sample Name").str.contains("KD", literal=True)) &
                (pl.col(f"{rbp}_{position}_binding") == 1)
            )
            .unique(subset=["rMATS Event ID"])
        )
        
        # Convert to pandas
        rbp_df = rbp_data_filtered.to_pandas()
    
        # Print to check
        # print(rbp_df)
        # Add a new column based on significance (significant if FDR <= 0.05 and abs dPSI >= 0.1
        rbp_df['Significant'] = np.where(
            (rbp_df['FDR'] <= 0.05) & (rbp_df['DeltaPSI'].abs() >= 0.1),
            1,
            0
        )
        
        # Count total events and significant events
        total_events = len(rbp_df)
        num_significant = rbp_df['Significant'].sum()
        
        # Skip if all events are not significant (all zeros in Significant column)
        if num_significant == 0:
            print(f"Skipping {rbp} at position {position}: No significant events")
            continue
    
        # Make training data
        smaller_df = rbp_df[[f'{rbp}_{position}_shap', 'Significant', 'rMATS Event ID']].copy()
        
        smaller_df['absolute_shap'] = smaller_df[f'{rbp}_{position}_shap'].abs()
        
        smaller_df = smaller_df.rename(columns={'rMATS Event ID': 'Event_ID'})
        
        smaller_df = smaller_df[['absolute_shap', 'Significant', 'Event_ID']]
    
        # Print to check
        # print(smaller_df)
    
        # Training logistic regression model
        
        # Prepare data
        X = smaller_df[['absolute_shap']].values  # Features
        y = smaller_df['Significant'].values      # Target
        
        # Train a classifier on all data
        classifier = LogisticRegression()
        classifier.fit(X, y)
        
        # Get predicted probabilities for the same data
        y_pred_proba = classifier.predict_proba(X)[:, 1]  # Probability of class 1
    
        # Calculate ROC curve
        fpr, tpr, thresholds_roc = roc_curve(y, y_pred_proba)
        roc_auc = auc(fpr, tpr)
    
        # Calculate PRC
        precision, recall, thresholds_pr = precision_recall_curve(y, y_pred_proba)
        avg_precision = average_precision_score(y, y_pred_proba)
        
        # Store the results with event counts
        results_list.append({
            'feature': f'{rbp}_{position}',
            'AUROC': roc_auc,
            'AUPRC': avg_precision,
            'total_events': total_events,
            'num_significant': num_significant
        })
        
# Create final results dataframe
results_df = pd.DataFrame(results_list)
print("\nFinal Results:")
print(results_df)
# Out:
# Skipping DDX51 at position 4: No significant events
# Skipping SF3B1 at position 2: No significant events
# Skipping SF3B1 at position 3: No significant events
# Skipping SF3B1 at position 4: No significant events
# Skipping SF3B1 at position 6: No significant events
# Skipping DDX42 at position 6: No significant events
# Skipping ADAT1 at position 3: No significant events
# Skipping ADAT1 at position 4: No significant events
# Skipping GNL3 at position 1: No significant events
# Skipping GNL3 at position 2: No significant events
# Skipping GNL3 at position 4: No significant events
# Skipping RPS6 at position 5: No significant events
# Skipping DDX47 at position 5: No significant events
# Skipping DDX47 at position 6: No significant events
# Skipping SERBP1 at position 6: No significant events
# Skipping TBRG4 at position 6: No significant events
# Skipping UTP3 at position 1: No significant events
# Skipping UTP3 at position 2: No significant events
# Skipping UTP3 at position 3: No significant events
# Skipping UTP3 at position 4: No significant events
# Skipping UTP3 at position 5: No significant events
# Skipping UTP3 at position 6: No significant events
# Skipping AARS at position 2: No significant events
# Skipping AARS at position 4: No significant events
# Skipping AARS at position 6: No significant events
# Skipping DDX21 at position 2: No significant events
# Skipping DDX21 at position 4: No significant events
# Skipping SUPV3L1 at position 1: No significant events
# Skipping SUPV3L1 at position 2: No significant events
# Skipping SUPV3L1 at position 4: No significant events
# Skipping SUPV3L1 at position 5: No significant events
# Skipping SUPV3L1 at position 6: No significant events
# Skipping PPIL4 at position 1: No significant events
# Skipping PPIL4 at position 2: No significant events
# Skipping PPIL4 at position 5: No significant events
# Skipping PUS1 at position 1: No significant events
# Skipping PUS1 at position 2: No significant events
# Skipping PUS1 at position 3: No significant events
# Skipping PUS1 at position 4: No significant events
# Skipping PUS1 at position 5: No significant events
# Skipping PUS1 at position 6: No significant events
# Skipping MORC2 at position 5: No significant events
# Skipping CPEB4 at position 1: No significant events
# Skipping CPEB4 at position 5: No significant events
# Skipping METTL1 at position 1: No significant events
# Skipping METTL1 at position 2: No significant events
# Skipping METTL1 at position 4: No significant events
# Skipping RYBP at position 1: No significant events
# Skipping RYBP at position 2: No significant events
# Skipping RYBP at position 3: No significant events
# Skipping RYBP at position 4: No significant events
# Skipping ABCF1 at position 4: No significant events
# Skipping ABCF1 at position 5: No significant events
# Skipping ABCF1 at position 6: No significant events
# Skipping SDAD1 at position 1: No significant events
# Skipping SDAD1 at position 3: No significant events
# Skipping SDAD1 at position 5: No significant events
# Skipping SDAD1 at position 6: No significant events
# Skipping KHDRBS1 at position 1: No significant events
# Skipping SBDS at position 1: No significant events
# Skipping SBDS at position 2: No significant events
# Skipping SBDS at position 3: No significant events
# Skipping SBDS at position 4: No significant events
# Skipping SBDS at position 5: No significant events
# Skipping SBDS at position 6: No significant events
# Skipping TAF15 at position 5: No significant events
# Skipping TAF15 at position 6: No significant events
# Skipping HNRNPA1 at position 1: No significant events
# Skipping HNRNPA1 at position 2: No significant events
# Skipping HNRNPA1 at position 4: No significant events
# Skipping HNRNPA1 at position 5: No significant events
# Skipping HNRNPA1 at position 6: No significant events
# Skipping RNF187 at position 1: No significant events
# Skipping RNF187 at position 2: No significant events
# Skipping RNF187 at position 5: No significant events
# Skipping NSUN2 at position 2: No significant events
# Skipping NSUN2 at position 3: No significant events
# Skipping NSUN2 at position 4: No significant events
# Skipping NSUN2 at position 5: No significant events
# Skipping NSUN2 at position 6: No significant events
# Skipping RPS10 at position 1: No significant events
# Skipping RPS10 at position 3: No significant events
# Skipping RPS10 at position 4: No significant events
# Skipping RPS10 at position 5: No significant events
# Skipping RPS10 at position 6: No significant events
# Skipping WDR43 at position 2: No significant events
# Skipping RPS11 at position 1: No significant events
# Skipping RPS11 at position 2: No significant events
# Skipping RPS11 at position 3: No significant events
# Skipping RPS11 at position 4: No significant events
# Skipping RPS11 at position 5: No significant events
# Skipping RPS11 at position 6: No significant events
# Skipping HNRNPU at position 1: No significant events
# Skipping HNRNPU at position 2: No significant events
# Skipping HNRNPU at position 3: No significant events
# Skipping HNRNPU at position 4: No significant events
# Skipping HNRNPU at position 5: No significant events
# Skipping HNRNPU at position 6: No significant events
# Skipping GARS at position 3: No significant events
# Skipping APEX1 at position 4: No significant events
# Skipping APEX1 at position 5: No significant events
# Skipping SRSF9 at position 6: No significant events
# Skipping UTP18 at position 6: No significant events
# Skipping SAFB2 at position 1: No significant events
# Skipping SLBP at position 1: No significant events
# Skipping SLBP at position 2: No significant events
# Skipping SLBP at position 3: No significant events
# Skipping SLBP at position 4: No significant events
# Skipping SLBP at position 5: No significant events
# Skipping SLBP at position 6: No significant events
# Skipping WDR3 at position 1: No significant events
# Skipping WDR3 at position 2: No significant events
# Skipping WDR3 at position 4: No significant events
# Skipping WDR3 at position 5: No significant events
# Skipping WDR3 at position 6: No significant events
# Skipping LARP7 at position 1: No significant events
# Skipping LARP7 at position 2: No significant events
# Skipping LARP7 at position 4: No significant events
# Skipping LARP7 at position 5: No significant events
# Skipping LARP7 at position 6: No significant events
# Skipping WRN at position 1: No significant events
# Skipping WRN at position 3: No significant events
# Skipping WRN at position 4: No significant events
# Skipping EEF2 at position 1: No significant events
# Skipping EEF2 at position 3: No significant events
# Skipping EEF2 at position 4: No significant events
# Skipping EEF2 at position 5: No significant events
# Skipping EEF2 at position 6: No significant events
#
# Final Results:
#      feature     AUROC     AUPRC  total_events  num_significant
# 0    DDX51_1  0.425224  0.023194          1707               45
# 1    DDX51_2  0.347523  0.030100          4172              120
# 2    DDX51_3  0.427871  0.022483          1084               27
# 3    DDX51_5  0.417626  0.032173           387               13
# 4    DDX51_6  0.500000  0.026316           228                6
# ..       ...       ...       ...           ...              ...
# 701    AQR_2  0.393828  0.010794         79772             1149
# 702    AQR_3  0.628282  0.024302         63009             1022
# 703    AQR_4  0.651459  0.032690         77219             1089
# 704    AQR_5  0.645444  0.028611         65234             1283
# 705    AQR_6  0.388553  0.010002         76311              976
#
# [706 rows x 5 columns]

# %%
# Save and sort results

results_df.to_csv('v2_K562_auroc_auprc_results.csv', index=False)

results_df = results_df.sort_values(by=['AUROC', 'AUPRC'], ascending=[False, False])

results_df2 = results_df.sort_values(by=['AUPRC', 'AUROC'], ascending=[False, False])

# %%
# Best ROCs
features = ["SRSF9_4", "HLTF_4", "RPS6_6", "SSB_2", "AARS_3"]
# results_df = plot_best_curves(features, K562_data, plot=True, save_dir='K562_ROC_plots')

# %%
# Best PRCs
features = ["SRSF9_4", "KHDRBS1_2", "SAFB2_6", "WRN_2", "SERBP1_5"]
# results_df = plot_best_curves(features, K562_data, plot=True, save_dir='K562_PRC_plots')
