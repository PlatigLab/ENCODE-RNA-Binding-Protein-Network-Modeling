# %%
def read_rbps(filepath):
    with open(filepath) as f:
        return set(line.strip() for line in f if line.strip())

# Read all four files
K562_shrna_rbps = read_rbps("/project/PlatigLab/users/reece/ENCODE-RNA-Binding-Protein-Network-Modeling/analysis/01_create_RBP_ML_input/3_assign_eCLIP_to_splice_junctions/output/eclip_and_shrna_rbps/K562_shrna_rbps.txt")
HepG2_shrna_rbps = read_rbps("/project/PlatigLab/users/reece/ENCODE-RNA-Binding-Protein-Network-Modeling/analysis/01_create_RBP_ML_input/3_assign_eCLIP_to_splice_junctions/output/eclip_and_shrna_rbps/HepG2_shrna_rbps.txt")
eclip_HepG2 = read_rbps("/project/PlatigLab/users/reece/ENCODE-RNA-Binding-Protein-Network-Modeling/analysis/01_create_RBP_ML_input/3_assign_eCLIP_to_splice_junctions/output/eclip_and_shrna_rbps/HepG2_eclip_rbps.txt")
eclip_K562 = read_rbps("/project/PlatigLab/users/reece/ENCODE-RNA-Binding-Protein-Network-Modeling/analysis/01_create_RBP_ML_input/3_assign_eCLIP_to_splice_junctions/output/eclip_and_shrna_rbps/K562_eclip_rbps.txt")

K562_eclip_only = eclip_K562 - K562_shrna_rbps
print(f"K562: {K562_eclip_only}")

HepG2_eclip_only = eclip_HepG2 - HepG2_shrna_rbps
print(f"HepG2: {HepG2_eclip_only}")
# Out:
# K562: {'NIPBL', 'SAFB', 'NOLC1', 'ZC3H11A', 'DDX42', 'EXOSC5', 'ZNF622', 'MORC2', 'RYBP', 'DDX21', 'APEX1', 'RPS6', 'DDX6', 'GNL3', 'ELAC2', 'FXR2', 'NPM1', 'TRA2A', 'RPS3', 'METTL1', 'SRSF7', 'PRPF8', 'ELAVL1', 'XRCC6', 'SRSF9', 'ADAT1', 'ZNF800', 'DDX43', 'DGCR8', 'RPS11', 'SDAD1', 'EIF4E', 'IGF2BP1', 'RNF187', 'SF3B1', 'GARS', 'EXOSC10', 'YWHAG'}
# HepG2: {'EIF3H', 'SAFB', 'NOLC1', 'ZC3H11A', 'EXOSC5', 'WDR43', 'RBM5', 'FXR2', 'DROSHA', 'RPS3', 'PABPN1', 'STAU2', 'CDC40', 'SRSF7', 'ZNF800', 'DGCR8', 'SDAD1', 'IGF2BP1', 'AGGF1', 'POLR2G'}

# %%
K562_shrna_rbps
# Out:
# {'AARS',
#  'AATF',
#  'ABCF1',
#  'AGGF1',
#  'AKAP1',
#  'AKAP8L',
#  'APOBEC3C',
#  'AQR',
#  'BCCIP',
#  'BCLAF1',
#  'BUD13',
#  'CPEB4',
#  'CPSF6',
#  'CSTF2',
#  'CSTF2T',
#  'DDX1',
#  'DDX24',
#  'DDX3X',
#  'DDX47',
#  'DDX51',
#  'DDX52',
#  'DDX55',
#  'DDX59',
#  'DDX6',
#  'DHX30',
#  'DKC1',
#  'DROSHA',
#  'EEF2',
#  'EFTUD2',
#  'EIF3D',
#  'EIF3G',
#  'EIF4G2',
#  'EWSR1',
#  'FAM120A',
#  'FASTKD2',
#  'FKBP4',
#  'FMR1',
#  'FTO',
#  'FUBP3',
#  'FUS',
#  'FXR1',
#  'G3BP1',
#  'GEMIN5',
#  'GPKOW',
#  'GRSF1',
#  'GRWD1',
#  'GTF2F1',
#  'HLTF',
#  'HNRNPA1',
#  'HNRNPC',
#  'HNRNPK',
#  'HNRNPL',
#  'HNRNPM',
#  'HNRNPU',
#  'HNRNPUL1',
#  'IGF2BP2',
#  'IGF2BP3',
#  'ILF3',
#  'KHDRBS1',
#  'KHSRP',
#  'LARP4',
#  'LARP7',
#  'LIN28B',
#  'LSM11',
#  'MATR3',
#  'MBNL1',
#  'METAP2',
#  'MTPAP',
#  'NCBP2',
#  'NIP7',
#  'NKRF',
#  'NOL12',
#  'NONO',
#  'NSUN2',
#  'PABPC4',
#  'PCBP1',
#  'PCBP2',
#  'PHF6',
#  'PPIG',
#  'PPIL4',
#  'PRPF4',
#  'PRPF8',
# ...
