# %%
import pandas as pd
df = pd.read_csv("/project/PlatigLab/users/reece/ENCODE-RNA-Binding-Protein-Network-Modeling/analysis/07_reece_biological_validations/1_for_figures/3_Crispr_KD/Helpers/final_combined_results.csv")

              
filtered_df = df[
    (df["Feature"] == "RPS3_3_binding") &
    (df["dPSI"].abs() > 0) &
    (df["FDR"] <= 0.1)
]

# %%
filtered_df.to_csv("test.csv")
