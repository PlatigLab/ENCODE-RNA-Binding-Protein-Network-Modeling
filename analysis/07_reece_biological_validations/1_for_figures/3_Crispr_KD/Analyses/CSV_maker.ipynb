# %%
import polars as pl
from pathlib import Path

folders = ["new_FINAL_results"]

combined = pl.concat([
    pl.read_csv(csv)
    for folder in folders
    for csv in Path(folder).glob("*.csv")
], how="diagonal_relaxed")

combined.write_csv("final_combined_results.csv")
print(combined.shape)
# Out:
# (43330, 10)
