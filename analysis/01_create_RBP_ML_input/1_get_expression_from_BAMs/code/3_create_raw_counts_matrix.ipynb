# %% [markdown]
# # Create Counts Matrix from Raw Counts

# %% [markdown]
# ## Purpose:
#
# * Take the counts files per `ENCODE` experiment accession
# * Do data sanity/validation checks
# * Join all the counts tables together, per cell line, to create counts matrix
# * Clean up counts matrix labelling and remove extra control samples
# * Output matrices, gene length metadata, and `RBP KD` to `Control Accession` tables

# %% [markdown]
# ## Packages and Options

# %%
from IPython.core.interactiveshell import InteractiveShell
InteractiveShell.ast_node_interactivity = "all"

import pandas as pd
pd.set_option('display.max_rows', 1000000)
pd.set_option('display.max_columns', 1000000)
pd.set_option('display.max_colwidth', 10000000)

import glob
import matplotlib.pyplot as plt
import seaborn as sns

# %% [markdown]
# ## Load Metadata and Filter to Relevant Experiments

# %%
# load shrna metadata and subset to poly-adenylated mRNA to avoid the total RNA samples
shrna_metadata = pd.read_csv("../../../inputs/metadata/ENCODE_shRNA_knockdown_FASTQ_metadata.tsv", sep="\t")
shrna_metadata = shrna_metadata[shrna_metadata["Library made from"]=="polyadenylated mRNA"]

shrna_metadata.head()
# Out:
#   File accession File format File type  File format type Output type  \
# 0    ENCFF258AKK       fastq     fastq               NaN       reads
# 1    ENCFF988NMV       fastq     fastq               NaN       reads
# 2    ENCFF205QCK       fastq     fastq               NaN       reads
# 3    ENCFF028JDE       fastq     fastq               NaN       reads
# 4    ENCFF060SHK       fastq     fastq               NaN       reads
#
#    File assembly Experiment accession          Assay  \
# 0            NaN          ENCSR584UYK  shRNA RNA-seq
# 1            NaN          ENCSR584UYK  shRNA RNA-seq
# 2            NaN          ENCSR584UYK  shRNA RNA-seq
# 3            NaN          ENCSR584UYK  shRNA RNA-seq
# 4            NaN          ENCSR774AEQ  shRNA RNA-seq
#
#                      Donor(s) Biosample term id Biosample term name  \
# 0  /human-donors/ENCDO000AAC/       EFO:0001187               HepG2
# 1  /human-donors/ENCDO000AAC/       EFO:0001187               HepG2
# 2  /human-donors/ENCDO000AAC/       EFO:0001187               HepG2
# 3  /human-donors/ENCDO000AAC/       EFO:0001187               HepG2
# 4  /human-donors/ENCDO000AAD/       EFO:0002067                K562
#
#   Biosample type Biosample organism  Biosample treatments  \
# 0      cell line       Homo sapiens                   NaN
# 1      cell line       Homo sapiens                   NaN
# 2      cell line       Homo sapiens                   NaN
# 3      cell line       Homo sapiens                   NaN
# 4      cell line       Homo sapiens                   NaN
#
#    Biosample treatments amount  Biosample treatments duration  \
# 0                          NaN                            NaN
# 1                          NaN                            NaN
# 2                          NaN                            NaN
# 3                          NaN                            NaN
# 4                          NaN                            NaN
#
#   Biosample genetic modifications methods  \
# 0                                    RNAi
# 1                                    RNAi
# 2                                    RNAi
# 3                                    RNAi
# 4                                    RNAi
#
#   Biosample genetic modifications categories  \
# 0                               interference
# 1                               interference
# 2                               interference
# 3                               interference
# 4                               interference
#
#   Biosample genetic modifications targets  \
# 0                                     NaN
# 1                                     NaN
# 2                                     NaN
# 3                                     NaN
# 4                                     NaN
#
#    Biosample genetic modifications gene targets  \
# 0                                           NaN
# 1                                           NaN
# 2                                           NaN
# 3                                           NaN
# 4                                           NaN
#
#    Biosample genetic modifications site coordinates  \
# 0                                               NaN
# 1                                               NaN
# 2                                               NaN
# 3                                               NaN
# 4                                               NaN
#
#    Biosample genetic modifications zygosity Experiment target  \
# 0                                       NaN               NaN
# 1                                       NaN               NaN
# 2                                       NaN               NaN
# 3                                       NaN               NaN
# 4                                       NaN               NaN
#
#      Library made from Library depleted in  \
# 0  polyadenylated mRNA                 NaN
# 1  polyadenylated mRNA                 NaN
# 2  polyadenylated mRNA                 NaN
# 3  polyadenylated mRNA                 NaN
# 4  polyadenylated mRNA                 NaN
#
#                                    Library extraction method  \
# 0  Maxwell 16 LEV simpleRNA Cells Kit (Promega cat#: AS1270)
# 1  Maxwell 16 LEV simpleRNA Cells Kit (Promega cat#: AS1270)
# 2  Maxwell 16 LEV simpleRNA Cells Kit (Promega cat#: AS1270)
# 3  Maxwell 16 LEV simpleRNA Cells Kit (Promega cat#: AS1270)
# 4  Maxwell 16 LEV simpleRNA Cells Kit (Promega cat#: AS1270)
#
#    Library lysis method  Library crosslinking method Library strand specific  \
# 0                   NaN                          NaN                 reverse
# 1                   NaN                          NaN                 reverse
# 2                   NaN                          NaN                 reverse
# 3                   NaN                          NaN                 reverse
# 4                   NaN                          NaN                 reverse
#
#   Experiment date released Project  RBNS protein concentration  \
# 0               2017-12-06  ENCODE                         NaN
# 1               2017-12-06  ENCODE                         NaN
# 2               2017-12-06  ENCODE                         NaN
# 3               2017-12-06  ENCODE                         NaN
# 4               2021-01-28  ENCODE                         NaN
#
#   Library fragmentation method Library size range  Biological replicate(s)  \
# 0   chemical (Illumina TruSeq)               >200                        1
# 1   chemical (Illumina TruSeq)               >200                        2
# 2   chemical (Illumina TruSeq)               >200                        2
# 3   chemical (Illumina TruSeq)               >200                        1
# 4   chemical (Illumina TruSeq)               >200                        2
#
#   Technical replicate(s)  Read length  Mapped read length      Run type  \
# 0                    1_1          100                 NaN  paired-ended
# 1                    2_1          100                 NaN  paired-ended
# 2                    2_1          100                 NaN  paired-ended
# 3                    1_1          100                 NaN  paired-ended
# 4                    2_1          100                 NaN  paired-ended
#
#    Paired end          Paired with  Index of  Derived from        Size  \
# 0           1  /files/ENCFF028JDE/       NaN           NaN  1994094569
# 1           1  /files/ENCFF205QCK/       NaN           NaN  2338694468
# 2           2  /files/ENCFF988NMV/       NaN           NaN  2356878462
# 3           2  /files/ENCFF258AKK/       NaN           NaN  2037315157
# 4           2  /files/ENCFF108KTH/       NaN           NaN  1946548816
#
#                        Lab                            md5sum          dbxrefs  \
# 0  Brenton Graveley, UConn  3d23629ac0b7f322dfa14662bd726f38  SRA:SRR14845888
# 1  Brenton Graveley, UConn  c915da979858c0bb6200c273f9975ea0  SRA:SRR14845889
# 2  Brenton Graveley, UConn  cf1da44aa1aaf1ce0cee0765e1bc0bea  SRA:SRR14845889
# 3  Brenton Graveley, UConn  9116223227862073b09a2fa2585a52ab  SRA:SRR14845888
# 4  Brenton Graveley, UConn  a0ba849e7778a2d1e258f1843188537f  SRA:SRR14834555
#
#                                                                  File download URL  \
# 0  https://www.encodeproject.org/files/ENCFF258AKK/@@download/ENCFF258AKK.fastq.gz
# 1  https://www.encodeproject.org/files/ENCFF988NMV/@@download/ENCFF988NMV.fastq.gz
# 2  https://www.encodeproject.org/files/ENCFF205QCK/@@download/ENCFF205QCK.fastq.gz
# 3  https://www.encodeproject.org/files/ENCFF028JDE/@@download/ENCFF028JDE.fastq.gz
# 4  https://www.encodeproject.org/files/ENCFF060SHK/@@download/ENCFF060SHK.fastq.gz
#
#    Genome annotation             Platform Controlled by File Status  \
# 0                NaN  Illumina HiSeq 2500           NaN    released
# 1                NaN  Illumina HiSeq 2500           NaN    released
# 2                NaN  Illumina HiSeq 2500           NaN    released
# 3                NaN  Illumina HiSeq 2500           NaN    released
# 4                NaN  Illumina HiSeq 2500           NaN    released
#
#                                                                                     s3_uri  \
# 0  s3://encode-public/2017/11/20/ae51799c-275f-4979-97b6-32ec3fc23ea3/ENCFF258AKK.fastq.gz
# 1  s3://encode-public/2017/11/20/b13eb07a-8e4e-48a0-87df-621b8df8f50f/ENCFF988NMV.fastq.gz
# 2  s3://encode-public/2017/11/20/4c06bcaa-5e69-41a4-80bf-e66b7254dea2/ENCFF205QCK.fastq.gz
# 3  s3://encode-public/2017/11/20/26a15b10-9748-4098-8c78-71355d21d281/ENCFF028JDE.fastq.gz
# 4  s3://encode-public/2018/09/01/be4b9827-cf6d-4c3e-8aba-82d4ac556877/ENCFF060SHK.fastq.gz
#
#                                                                                                                                                                                                 Azure URL  \
# 0  https://datasetencode.blob.core.windows.net/dataset/2017/11/20/ae51799c-275f-4979-97b6-32ec3fc23ea3/ENCFF258AKK.fastq.gz?sv=2019-10-10&si=prod&sr=c&sig=9qSQZo4ggrCNpybBExU8SypuUZV33igI11xw0P7rB3c%3D
# 1  https://datasetencode.blob.core.windows.net/dataset/2017/11/20/b13eb07a-8e4e-48a0-87df-621b8df8f50f/ENCFF988NMV.fastq.gz?sv=2019-10-10&si=prod&sr=c&sig=9qSQZo4ggrCNpybBExU8SypuUZV33igI11xw0P7rB3c%3D
# 2  https://datasetencode.blob.core.windows.net/dataset/2017/11/20/4c06bcaa-5e69-41a4-80bf-e66b7254dea2/ENCFF205QCK.fastq.gz?sv=2019-10-10&si=prod&sr=c&sig=9qSQZo4ggrCNpybBExU8SypuUZV33igI11xw0P7rB3c%3D
# 3  https://datasetencode.blob.core.windows.net/dataset/2017/11/20/26a15b10-9748-4098-8c78-71355d21d281/ENCFF028JDE.fastq.gz?sv=2019-10-10&si=prod&sr=c&sig=9qSQZo4ggrCNpybBExU8SypuUZV33igI11xw0P7rB3c%3D
# 4  https://datasetencode.blob.core.windows.net/dataset/2018/09/01/be4b9827-cf6d-4c3e-8aba-82d4ac556877/ENCFF060SHK.fastq.gz?sv=2019-10-10&si=prod&sr=c&sig=9qSQZo4ggrCNpybBExU8SypuUZV33igI11xw0P7rB3c%3D
#
#    File analysis title  File analysis status  \
# 0                  NaN                   NaN
# 1                  NaN                   NaN
# 2                  NaN                   NaN
# 3                  NaN                   NaN
# 4                  NaN                   NaN
#
#                         Audit WARNING Audit NOT_COMPLIANT  Audit ERROR
# 0  missing biosample characterization    missing spikeins          NaN
# 1  missing biosample characterization    missing spikeins          NaN
# 2  missing biosample characterization    missing spikeins          NaN
# 3  missing biosample characterization    missing spikeins          NaN
# 4  missing biosample characterization                 NaN          NaN

# %%
# key is cell line and value is all experiments in that cell line
cell_line_experiments = {}

for cell_line in ["K562", "HepG2"]: 
    # subset to cell line of interest and KD experiments (as we identify everything by KD identifiers) 
    # get all unique experiment accessions
    cell_line_experiments[cell_line] = shrna_metadata[
            (shrna_metadata["Biosample term name"]==cell_line) & (shrna_metadata["Experiment target"].notna())
        ]["Experiment accession"].unique().tolist()

print(cell_line_experiments)
# Out:
# {'K562': ['ENCSR473KFO', 'ENCSR688GVV', 'ENCSR953IQF', 'ENCSR608IXR', 'ENCSR629XTS', 'ENCSR384BDV', 'ENCSR363QIA', 'ENCSR793QPX', 'ENCSR016OIX', 'ENCSR233UVM', 'ENCSR648QFY', 'ENCSR792XFP', 'ENCSR849STR', 'ENCSR831YGP', 'ENCSR947OIM', 'ENCSR268JDD', 'ENCSR561CBC', 'ENCSR984CLJ', 'ENCSR222ABK', 'ENCSR778SIU', 'ENCSR562CCA', 'ENCSR949RMX', 'ENCSR874ZLI', 'ENCSR678WOA', 'ENCSR023HWI', 'ENCSR902WSK', 'ENCSR267RHP', 'ENCSR885YOI', 'ENCSR000YYN', 'ENCSR118XYK', 'ENCSR152IWT', 'ENCSR606QIX', 'ENCSR081XRA', 'ENCSR524YXQ', 'ENCSR717SJA', 'ENCSR528ASX', 'ENCSR624OUI', 'ENCSR098NHI', 'ENCSR492BKM', 'ENCSR117WLY', 'ENCSR618IQH', 'ENCSR907UTB', 'ENCSR191VWK', 'ENCSR253DCB', 'ENCSR812EIA', 'ENCSR379VXW', 'ENCSR222COT', 'ENCSR517JHY', 'ENCSR112YTD', 'ENCSR231PWH', 'ENCSR246SOU', 'ENCSR134JRE', 'ENCSR079IPT', 'ENCSR813NZP', 'ENCSR608IAI', 'ENCSR967QNT', 'ENCSR795VAK', 'ENCSR809ISU', 'ENCSR794NUE', 'ENCSR395FYF', 'ENCSR555LCE', 'ENCSR398GHW', 'ENCSR563YIS', 'ENCSR040FSN', 'ENCSR227AVS', 'ENCSR334BTA', 'ENCSR835RMN', 'ENCSR066VOO', 'ENCSR244SIO', 'ENCSR770OWW', 'ENCSR529MBZ', 'ENCSR560AYQ', 'ENCSR000KYM', 'ENCSR611ZAL', 'ENCSR904CJQ', 'ENCSR256PLH', 'ENCSR338CON', 'ENCSR310VND', 'ENCSR067LLB', 'ENCSR952RRH', 'ENCSR302JQA', 'ENCSR361LBE', 'ENCSR780YFF', 'ENCSR143UET', 'ENCSR325OOM', 'ENCSR408SDL', 'ENCSR527IVX', 'ENCSR783YSQ', 'ENCSR188IPO', 'ENCSR286OKW', 'ENCSR232XRZ', 'ENCSR101OPF', 'ENCSR126ARZ', 'ENCSR410ZPU', 'ENCSR783LUA', 'ENCSR958NDU', 'ENCSR306EIU', 'ENCSR874DVZ', 'ENCSR911DGK', 'ENCSR341PZW', 'ENCSR599UDS', 'ENCSR077BPR', 'ENCSR634KBO', 'ENCSR007XKL', 'ENCSR004RGI', 'ENCSR234YMW', 'ENCSR454KYR', 'ENCSR392HSJ', 'ENCSR398HXV', 'ENCSR624XHG', 'ENCSR898OPN', 'ENCSR712CSN', 'ENCSR660ETT', 'ENCSR258VGD', 'ENCSR494UDF', 'ENCSR322XVS', 'ENCSR954HAY', 'ENCSR584LDM', 'ENCSR605MFS', 'ENCSR511BNY', 'ENCSR336DFS', 'ENCSR079LMZ', 'ENCSR281IUF', 'ENCSR029LGJ', 'ENCSR829EFL', 'ENCSR222LRL', 'ENCSR598YQX', 'ENCSR745WVZ', 'ENCSR060KRD', 'ENCSR577OVP', 'ENCSR530BOP', 'ENCSR535YPK', 'ENCSR602AWR', 'ENCSR082UWF', 'ENCSR921KDS', 'ENCSR269HQA', 'ENCSR210KJB', 'ENCSR812TLY', 'ENCSR181RLB', 'ENCSR205VSQ', 'ENCSR208GPE', 'ENCSR788YGG', 'ENCSR850PWM', 'ENCSR192BPV', 'ENCSR560RSZ', 'ENCSR963RLK', 'ENCSR306IOF', 'ENCSR552NBS', 'ENCSR943LIB', 'ENCSR362XMY', 'ENCSR777EDL', 'ENCSR386YEV', 'ENCSR754RJA', 'ENCSR129ROE', 'ENCSR309PPC', 'ENCSR721MXZ', 'ENCSR164TLB', 'ENCSR746NIM', 'ENCSR076PMZ', 'ENCSR952QDQ', 'ENCSR047EEG', 'ENCSR201WFU', 'ENCSR843LYF', 'ENCSR345VVZ', 'ENCSR631RFX', 'ENCSR546MBH', 'ENCSR342EDG', 'ENCSR529JNJ', 'ENCSR823WTA', 'ENCSR762FEO', 'ENCSR774BXV', 'ENCSR694LKY', 'ENCSR904BCZ', 'ENCSR844QNT', 'ENCSR891AXF', 'ENCSR231DXJ', 'ENCSR453HKS', 'ENCSR165VBD', 'ENCSR945GUR', 'ENCSR113PYX', 'ENCSR034VBA', 'ENCSR155EZL', 'ENCSR047IUS', 'ENCSR192GBD', 'ENCSR300QFQ', 'ENCSR048BWH', 'ENCSR312SRB', 'ENCSR545AIK', 'ENCSR973QSV', 'ENCSR925RNE', 'ENCSR810FHY', 'ENCSR866XLI', 'ENCSR927XBT', 'ENCSR165BCF', 'ENCSR927TSP', 'ENCSR219DXZ', 'ENCSR556FNN', 'ENCSR770LYW', 'ENCSR775TMW', 'ENCSR448JAM', 'ENCSR416ZJH', 'ENCSR611LQB', 'ENCSR169QQW', 'ENCSR978CSQ', 'ENCSR558XNA', 'ENCSR678MVE', 'ENCSR047AJA', 'ENCSR385UPQ', 'ENCSR251ABP', 'ENCSR856CJK', 'ENCSR940GIC', 'ENCSR778WPL'], 'HepG2': ['ENCSR184YDW', 'ENCSR756VLW', 'ENCSR736TAW', 'ENCSR896CFV', 'ENCSR635BOO', 'ENCSR676SDU', 'ENCSR204QKA', 'ENCSR902VPO', 'ENCSR998RZI', 'ENCSR094KBY', 'ENCSR746EKS', 'ENCSR610AEI', 'ENCSR957EEG', 'ENCSR193FFA', 'ENCSR016IDR', 'ENCSR147ZBD', 'ENCSR269SJB', 'ENCSR755KOM', 'ENCSR116QBU', 'ENCSR667RIA', 'ENCSR634KHL', 'ENCSR355OQC', 'ENCSR422JMS', 'ENCSR517JDK', 'ENCSR281KCL', 'ENCSR274KWA', 'ENCSR330KHN', 'ENCSR599PXD', 'ENCSR438UOT', 'ENCSR289HOV', 'ENCSR494VSD', 'ENCSR676EKU', 'ENCSR815JDY', 'ENCSR028YAQ', 'ENCSR744YVR', 'ENCSR366FFV', 'ENCSR110ZYD', 'ENCSR155BMF', 'ENCSR243IGA', 'ENCSR385TMY', 'ENCSR372UWV', 'ENCSR478FJK', 'ENCSR572AMC', 'ENCSR939ZRA', 'ENCSR486AIO', 'ENCSR296ERI', 'ENCSR300IEW', 'ENCSR093FHC', 'ENCSR318OXM', 'ENCSR424YSV', 'ENCSR542ESY', 'ENCSR431SXF', 'ENCSR519KXM', 'ENC ...

# %% [markdown]
# ## What percentage of Reads per `BAM` file were assigned?

# %%
for cell_line in cell_line_experiments: 
    percentage_assigned_reads = []

    for file in glob.glob("../output/1_experiment_counts/*.txt.summary"):
        
        # if the experiment accession is one we care about
        if file.split("/")[-1].split(".txt")[0] in cell_line_experiments[cell_line]: 
            
            tmp_df = pd.read_csv(file, sep="\t", index_col="Status")

            tmp_df = tmp_df.div(tmp_df.sum(axis=0), axis=1)

            percentage_assigned_reads.extend(
                tmp_df.loc["Assigned"].values.tolist()
            )
            
    plt.figure(dpi=200, figsize=(5,2))
    plt.title("{}: Percentage of Reads Assigned (X-axis) per Sample".format(cell_line))
    sns.swarmplot(percentage_assigned_reads, size=1)
    plt.show()
# Out:
# Text(0.5, 1.0, 'K562: Percentage of Reads Assigned (X-axis) per Sample')
# <Axes: title={'center': 'K562: Percentage of Reads Assigned (X-axis) per Sample'}>
# Text(0.5, 1.0, 'HepG2: Percentage of Reads Assigned (X-axis) per Sample')
# <Axes: title={'center': 'HepG2: Percentage of Reads Assigned (X-axis) per Sample'}>

# %% [markdown]
# ## Data Validations
#
# Check that:
# * Same genes are in all files
# * There are 4 files in all experiment counts files (1 known exception)

# %%
# random file as reference that is used to check that all files have expected contents 
reference_counts_file = pd.read_csv("../output/1_experiment_counts/ENCSR000KYM.txt", sep="\t", skiprows=1)

# for each counts file 
for file in glob.glob("../output/1_experiment_counts/*.txt"): 
    # load file 
    tmp_df = pd.read_csv(file, sep="\t", skiprows=1)
    
    # make sure that the same genes were counted in all files 
    assert set(tmp_df["Geneid"].to_list()) == set(reference_counts_file["Geneid"].to_list())
    
    # get the columns that are BAM-related to check there are 4 per file 
    # NOTE: there should only be 1 experiment where this is not the case 
    # (doesn't matter as the control BAM files are the same for other KDs as well)
    if len([column for column in tmp_df.columns.to_list() if ".bam" in column])!=4: 
        file.split("/")[-1]
# Out:
# 'ENCSR310VND.txt'

# %% [markdown]
# ## Create Counts Matrices per Cell Line

# %%
cell_line_matrices= {}

for cell_line in cell_line_experiments: 
    cell_line
    
    # matrix that we're creating for the cell line 
    joined_df = pd.DataFrame()
    
    # for each accession
    for accession in cell_line_experiments[cell_line]:
        
        # get the counts file for that accession and make sure it's only 1 file 
        accession_counts = glob.glob("../output/1_experiment_counts/*{}*.txt".format(accession))
        assert len(accession_counts)==1, accession 
        
        # read the counts file in 
        tmp_df = pd.read_csv(accession_counts[0], sep="\t", index_col="Geneid", skiprows=1)
        # subset to the columns related to BAM counts 
        tmp_df = tmp_df[[column for column in tmp_df.columns.to_list() if ".bam" in column]]
        
        # do outer join to make sure to capture all genes
        joined_df = joined_df.join(tmp_df, how="outer")
    
    # check that there are no null values in the matrix 
    assert joined_df.notnull().any().any()
    
    cell_line_matrices[cell_line] = joined_df
# Out:
# 'K562'
# 'HepG2'

# %% [markdown]
# ## Clean Up Matrices & Output
#
# * Format columns to be sample names
# * Remove samples that are duplicates of each other
# * Output matrices and `RBP KD` to `Control Accession` table

# %%
for cell_line in cell_line_matrices: 
    
    cell_line
    
    tmp_df = cell_line_matrices[cell_line]
    
    "Original shape: {}".format(tmp_df.shape)
    
    # get the last part of the BAM path that begins with RBP to be name
    tmp_df = tmp_df.rename(columns=lambda x: x.split("/")[-1])
    # sort the names of the columns 
    tmp_df = tmp_df.sort_index(axis=1)
    
    # key is RBP name and value is the control experiment accession 
    # (for control samples) or modified RBP KD name
    # this is for renaming columns 
    rename_dict = {}
    
    # key is RBP KD and value is control accession
    rbp_to_controls= {}
    
    # for each sample
    for sample in tmp_df.columns.to_list(): 
        
        # get the KD RBP control sample is associated with 
        kd_rbp = sample.split("_")[0]
        
        # if it's a control sample 
        if "_control_" in sample: 
            
            # get a control file by: 
            # subsetting metadata to cell line and RBP KD match 
            # getting any of the possible ENCODE files in the "Controlled by" section 
            # and then parsing out the ENCFF file id
            control_file = shrna_metadata[
                    (shrna_metadata["Biosample term name"]==cell_line) & (shrna_metadata["Experiment target"]=="{}-human".format(kd_rbp))
            ]["Controlled by"].to_list()[0].split(",")[0].split("/")[-2]
            assert "ENCFF" in control_file
            
            # get control accession by filtering to row with that file accession 
            # and looking at experiment accession column
            control_accession = shrna_metadata[shrna_metadata["File accession"]==control_file]["Experiment accession"].to_list()
            assert len(control_accession)==1
            
            # save association between KD RBP and control accession 
            rbp_to_controls[kd_rbp] = control_accession
            
            # save old sample name as key and value as 
            # replacing the RBP and control name with the accession 
            rename_dict[sample] = control_accession[0] + "_" + "CTRL" + "-" + sample.split("_")[3]
        
        elif "_KD_" in sample: 
            rename_dict[sample] = kd_rbp + "_" + sample.split("_")[1] + "-" + sample.split("_")[3]
    
    # convert KD RBP to control accession dict into DataFrame 
    # fix column names and output to CSV as this will be used downstream to
    # get expression for control samples of KD RBP samples
    pd.DataFrame.from_dict(rbp_to_controls).T.reset_index().rename(
        columns = {
            "index": "RBP KD", 
            0: "Control Accession"
        }, 
    ).to_csv(
        "../output/2_final_raw_counts_matrices/{}_RBP_KD_control_associations.tsv".format(cell_line),
        sep="\t", 
        index=False
    )
            
    # rename the columns of the matrix so that control samples correspond to the experiment accession
    tmp_df = tmp_df.rename(columns=rename_dict)    
    # remove all columns with duplicated names (EXCEPT for the first time the column is seen)
    tmp_df = tmp_df.loc[:, ~tmp_df.columns.duplicated()]
    
    
    "Final shape: {}".format(tmp_df.shape)
    
    tmp_df.head()
    
    # output as gzip'd TSV file 
    tmp_df.to_csv(
        "../output/2_final_raw_counts_matrices/{}_raw_counts_matrix.tsv.gz".format(cell_line), 
        sep="\t", 
        compression="gzip", 
        header=True, 
        index=True
    )
# Out:
# 'K562'
# 'Original shape: (57169, 846)'
# 'Final shape: (57169, 476)'
#           AARS_KD-1  AARS_KD-2  ENCSR572FFX_CTRL-1  ENCSR572FFX_CTRL-2  \
# Geneid
# A1BG              3          1                   1                   3
# A1BG-AS1         43         35                  39                  46
# A1CF              0          0                   0                   1
# A2M               1          0                   0                   1
# A2M-AS1           0          0                   0                   1
#
#           AATF_KD-1  AATF_KD-2  ENCSR815CVQ_CTRL-1  ENCSR815CVQ_CTRL-2  \
# Geneid
# A1BG              0          1                   1                   1
# A1BG-AS1         62         59                  54                  68
# A1CF              0          0                   1                   0
# A2M               0          0                   0                   0
# A2M-AS1           1          1                   0                   1
#
#           ABCF1_KD-1  ABCF1_KD-2  ENCSR032YMP_CTRL-1  ENCSR032YMP_CTRL-2  \
# Geneid
# A1BG               5           6                   0                   2
# A1BG-AS1          78          97                  55                  57
# A1CF               0           0                   0                   0
# A2M                4           1                   1                   0
# A2M-AS1            3           0                   0                   1
#
#           ABT1_KD-1  ABT1_KD-2  ENCSR260BQC_CTRL-1  ENCSR260BQC_CTRL-2  \
# Geneid
# A1BG              5          3                   4                   3
# A1BG-AS1         53         41                  19                  36
# A1CF              0          1                   0                   0
# A2M               0          0                  29                  26
# A2M-AS1           1          1                   2                   2
#
#           ADAR_KD-1  ADAR_KD-2  ENCSR667PLJ_CTRL-1  ENCSR667PLJ_CTRL-2  \
# Geneid
# A1BG              2          2                   3                   1
# A1BG-AS1         37         50                  33                  35
# A1CF              0          0                   0                   0
# A2M               1          0                   0                   0
# A2M-AS1           1          0                   0                   0
#
#           AGGF1_KD-1  AGGF1_KD-2  ENCSR143COQ_CTRL-1  ENCSR143COQ_CTRL-2  \
# Geneid
# A1BG               2           4                   5                   5
# A1BG-AS1          29          16                 132                  67
# A1CF               0           0                   0                   0
# A2M                1           1                   2                   0
# A2M-AS1            0           0                   1                   0
#
#           AGO1_KD-1  AGO1_KD-2  ENCSR084SCN_CTRL-1  ENCSR084SCN_CTRL-2  \
# Geneid
# A1BG              1          1                   3                   1
# A1BG-AS1         35         35                  41                  21
# A1CF              0          1                   1                   0
# A2M               0          1                   0                   0
# A2M-AS1           0          0                   0                   0
#
#           AKAP1_KD-1  AKAP1_KD-2  ENCSR913CAE_CTRL-1  ENCSR913CAE_CTRL-2  \
# Geneid
# A1BG               3           7                   4                   5
# A1BG-AS1          29          30                  46                  34
# A1CF               0           0                   0                   0
# A2M                0           0                   0                   0
# A2M-AS1            0           1                   0                   0
#
#           AKAP8L_KD-1  AKAP8L_KD-2  AKAP8_KD-1  AKAP8_KD-2  APOBEC3C_KD-1  \
# Geneid
# A1BG                6            6           2           6              0
# A1BG-AS1           15           29          62          42             67
# A1CF                0            0           1           0              1
# A2M                 2            2           0           0              1
# A2M-AS1             0            1           0           0              0
#
#           APOBEC3C_KD-2  ENCSR620PUP_CTRL-1  ENCSR620PUP_CTRL-2  AQR_KD-1  \
# Geneid
# A1BG                  2                   4                   7         3
# A1BG-AS1             95                  83                 156       138
# A1CF                  0                   0                   0         2
# A2M                   2                   0                   2        50
# A2M-AS1               1                   1                   0         0
#
#           AQR_KD-2  ENCSR718EWL_CTRL-1  ENCSR718EWL_CTRL-2  ASCC1_KD-1  \
# Geneid
# A1BG             2                   7                   6           3
# A1BG-AS1        80                 112                  78          38
# A1CF             3                   0                   1           0
# A2M             59                  33                  64           0
# A2M-AS1          0                   2                   0           0
#
#           ASCC1_KD-2  ATP5C1_KD-1  ATP5C1_KD-2  AUH_KD-1  AUH_KD-2  \
# Geneid
# A1BG               4            5            2         2         2
# A1BG-AS1          18           44           41       135       118
# A1CF               0            0            0         3         1
# A2M                0            1            2       161        63
# A2M-AS1            1            0            0         2         2
#
#           BCCIP_KD-1  BCCIP_KD-2  ENCSR245BNJ_CTRL-1  ENCSR245BNJ_CTRL-2  \
# Geneid
# A1BG               3           2                   0                   1
# A1BG-AS1          72          59                  47                  32
# A1CF               0           0                   0                   0
# A2M                5           2                   1                   0
# A2M-AS1            0           0                   1                   1
#
#           BCLAF1_KD-1  BCLAF1_KD-2  BOP1_KD-1  BOP1_KD-2  ENCSR424QCW_CTRL-1  \
# Geneid
# A1BG                1            2          1          0                   4
# A1BG-AS1           73           54         51         44                  27
# A1CF                0            0          1          2                   3
# A2M                 5            0        114        138                 107
# A2M-AS1             0            0          0          2                   0
#
#           ENCSR424QCW_CTRL-2  BUD13_KD-1  BUD13_KD-2  CCAR1_KD-1  CCAR1_KD-2  \
# Geneid
# A1BG                       1           5           2           1           2
# A1BG-AS1                  22          38          49          65          39
# A1CF                       1           0           1           0           0
# A2M                      219           5          38           0           0
# A2M-AS1                    1           1           0           1           0
#
#           CCAR2_KD-1  CCAR2_KD-2  CCDC124_KD-1  CCDC124_KD-2  CELF1_KD-1  \
# Geneid
# A1BG              11           3             1             5           8
# A1BG-AS1         176         104            95           111         108
# A1CF               0           0             0             0           0
# A2M                3           3             2             2           2
# A2M-AS1            2           2             0             0           0
#
#           CELF1_KD-2  CKAP4_KD-1  CKAP4_KD-2  ENCSR898ABR_CTRL-1  \
# Geneid
# A1BG               5           1           2                   2
# A1BG-AS1         121          37          31                  24
# A1CF               0           0           0                   0
# A2M                0          26          26                  24
# A2M-AS1            1           0           0                   0
#
#           ENCSR898ABR_CTRL-2  CNOT7_KD-1  CNOT7_KD-2  ENCSR419JMU_CTRL-1  \
# Geneid
# A1BG                       2           3           4                   1
# A1BG-AS1                  35          83         100                  39
# A1CF                       0           0           0                   0
# A2M                       27           0           1                   4
# A2M-AS1                    0           1           1                   1
#
#           ENCSR419JMU_CTRL-2  CPEB4_KD-1  CPEB4_KD-2  ENCSR031RRO_CTRL-1  \
# Geneid
# A1BG                       2           8           3                   2
# A1BG-AS1                  46         118          66                  91
# A1CF                       1           0           0                   0
# A2M                        1           1           2                   0
# A2M-AS1                    0           0           1                   1
#
#           ENCSR031RRO_CTRL-2  CPSF6_KD-1  CPSF6_KD-2  CPSF7_KD-1  CPSF7_KD-2  \
# Geneid
# A1BG                       5           3           4           0           0
# A1BG-AS1                  75          56          53          51          35
# A1CF                       1           1           2           0           0
# A2M                        1         123         115           0           0
# A2M-AS1                    3           0           2           1           0
#
#           CSTF2T_KD-1  CSTF2T_KD-2  CSTF2_KD-1  CSTF2_KD-2  DAZAP1_KD-1  \
# Geneid
# A1BG                5            3           1           0            4
# A1BG-AS1           60           78          32          53           58
# A1CF                0            0           0           0            0
# A2M                 0            1           0           0            0
# A2M-AS1             0            0           1           0            1
#
#           DAZAP1_KD-2  DDX19B_KD-1  DDX19B_KD-2  DDX1_KD-1  DDX1_KD-2  \
# Geneid
# A1BG                2            7            3          0          5
# A1BG-AS1           51           72           61         51         56
# A1CF                0            0            0          0          0
# A2M                 0            0            1          0          0
# A2M-AS1             1            1            0          0          0
#
#           DDX24_KD-1  DDX24_KD-2  DDX27_KD-1  DDX27_KD-2  DDX28_KD-1  \
# Geneid
# A1BG               2           2           3           2           3
# A1BG-AS1          49          39          41          40          70
# A1CF               0           0           0           0           0
# A2M                0           0           4           2           0
# A2M-AS1            1           0           2           0           1
#
#           DDX28_KD-2  ENCSR661HEL_CTRL-1  ENCSR661HEL_CTRL-2  DDX3X_KD-1  \
# Geneid
# A1BG               3                   0                   2           4
# A1BG-AS1          61                  33                  49          44
# A1CF               1                   0                   0           0
# A2M                0                   0                   0           0
# A2M-AS1            1                   0                   1           0
#
#           DDX3X_KD-2  DDX47_KD-1  DDX47_KD-2  DDX51_KD-1  DDX51_KD-2  \
# Geneid
# A1BG               1           2           6           4           4
# A1BG-AS1          38          97          79          80          80
# A1CF               0           0           0           0           0
# A2M                0           0           0           2           0
# A2M-AS1            0           6           0           0           0
#
#           DDX52_KD-1  DDX52_KD-2  DDX55_KD-1  DDX55_KD-2  DHX30_KD-1  \
# Geneid
# A1BG               3           3           2           1           3
# A1BG-AS1          67          62          26          34          47
# A1CF               0           0           0           1           0
# A2M                0           1           0           0           1
# A2M-AS1            0           1           1           1           1
#
#           DHX30_KD-2  DKC1_KD-1  DKC1_KD-2  DNAJC21_KD-1  DNAJC21_KD-2  \
# Geneid
# A1BG               3          2          3             4             3
# A1BG-AS1          41         33         40            56            58
# A1CF               0          0          0             0             0
# A2M                0          1          0             0             0
# A2M-AS1            0          1          1             1             0
#
#           DNAJC2_KD-1  DNAJC2_KD-2  DROSHA_KD-1  DROSHA_KD-2  \
# Geneid
# A1BG                2            1            1            7
# A1BG-AS1           41           35           56          110
# A1CF                0            0            0            0
# A2M                 0            0            4            5
# A2M-AS1             1            1            0            0
#
#           ENCSR164MUK_CTRL-1  ENCSR164MUK_CTRL-2  EEF2_KD-1  EEF2_KD-2  \
# Geneid
# A1BG                       1                   3          0          3
# A1BG-AS1                  56                  70         44         25
# A1CF                       0                   0          0          0
# A2M                        0                   0          1          5
# A2M-AS1                    2                   0          1          0
#
#           EFTUD2_KD-1  EFTUD2_KD-2  EIF2S1_KD-1  EIF2S1_KD-2  EIF2S2_KD-1  \
# Geneid
# A1BG                3            3            1            2            5
# A1BG-AS1          124           84           66           56          131
# A1CF                1            1            0            0            0
# A2M                 0            2            0            0           15
# A2M-AS1             0            1            0            0            0
#
#           EIF2S2_KD-2  ENCSR118EFE_CTRL-1  ENCSR118EFE_CTRL-2  EIF3A_KD-1  \
# Geneid
# A1BG                5                   1                   0           6
# A1BG-AS1          137                  67                  61          48
# A1CF                1                   0                   0           0
# A2M                33                  14                  10           0
# A2M-AS1             1                   0                   0           0
#
#           EIF3A_KD-2  EIF3D_KD-1  EIF3D_KD-2  EIF3G_KD-1  EIF3G_KD-2  \
# Geneid
# A1BG               0           5           3           2           4
# A1BG-AS1          35         126          72          52          47
# A1CF               0           0           0           0           0
# A2M                0           0           0           0           0
# A2M-AS1            0           0           0           1           0
#
#           EIF4B_KD-1  EIF4B_KD-2  EIF4G1_KD-1  EIF4G1_KD-2  EIF4G2_KD-1  \
# Geneid
# A1BG               0           2            1            2            5
# A1BG-AS1          26          31           40           59           95
# A1CF               0           0            0            1            1
# A2M                0           0            0            0            1
# A2M-AS1            1           0            0            1            0
#
#           EIF4G2_KD-2  ESF1_KD-1  ESF1_KD-2  EWSR1_KD-1  EWSR1_KD-2  \
# Geneid
# A1BG                3          1          3           1           1
# A1BG-AS1           90         43         85          33          24
# A1CF                0          1          3           0           0
# A2M                 1          0          1           0           0
# A2M-AS1             2          0          0           1           0
#
#           EXOSC9_KD-1  EXOSC9_KD-2  FAM120A_KD-1  FAM120A_KD-2  FASTKD2_KD-1  \
# Geneid
# A1BG                2            6             3             2             5
# A1BG-AS1           65           92            43            59            49
# A1CF                0            0             0             0             1
# A2M                 3            0             0             0             1
# A2M-AS1             0            0             2             0             0
#
#           FASTKD2_KD-2  FIP1L1_KD-1  FIP1L1_KD-2  FKBP4_KD-1  FKBP4_KD-2  \
# Geneid
# A1BG                 2            4            5           1           1
# A1BG-AS1            33           42           52          34          36
# A1CF                 1            0            0           1           0
# A2M                  0            0            1           2           0
# A2M-AS1              0            1            0           2           0
#
#           FMR1_KD-1  FMR1_KD-2  FTO_KD-1  FTO_KD-2  FUBP1_KD-1  FUBP1_KD-2  \
# Geneid
# A1BG              3          2         4         8           3           1
# A1BG-AS1         49         78        36        44          33          49
# A1CF              1          1         0         0           0           2
# A2M               0          0         0         1           0          43
# A2M-AS1           0          1         1         2           0           1
#
#           FUS_KD-1  FUS_KD-2  FXR1_KD-1  FXR1_KD-2  G3BP2_KD-1  G3BP2_KD-2  \
# Geneid
# A1BG             5         1          3          2           1           1
# A1BG-AS1        29        13         68         82          11           3
# A1CF             1         0          1          1           0           0
# A2M              0         0          1          3           0           0
# A2M-AS1          0         0          1          0           0           0
#
#           ENCSR344XID_CTRL-1  ENCSR344XID_CTRL-2  GEMIN5_KD-1  GEMIN5_KD-2  \
# Geneid
# A1BG                       2                   2            2            2
# A1BG-AS1                  24                  24           67           42
# A1CF                       0                   0            0            0
# A2M                        0                   0            1            1
# A2M-AS1                    0                   0            2            0
#
#           GLRX3_KD-1  GLRX3_KD-2  ENCSR174OYC_CTRL-1  ENCSR174OYC_CTRL-2  \
# Geneid
# A1BG               8           3                   3                   1
# A1BG-AS1          44          61                  67                  71
# A1CF              16          11                  11                  13
# A2M             1396        1531                1394                1722
# A2M-AS1            1           1                   4                   0
#
#           GPKOW_KD-1  GPKOW_KD-2  GRSF1_KD-1  GRSF1_KD-2  GRWD1_KD-1  \
# Geneid
# A1BG               7           2           4           5           1
# A1BG-AS1          69          72         291         147          32
# A1CF               0           0           0           0           0
# A2M                0           1           3           8           0
# A2M-AS1            2           0           0           2           1
#
#           GRWD1_KD-2  GTF2F1_KD-1  GTF2F1_KD-2  HDGF_KD-1  HDGF_KD-2  \
# Geneid
# A1BG               2            7            1          1          2
# A1BG-AS1          40           58           50         21         19
# A1CF               0            1            0          0          0
# A2M                1            3            0          0          2
# A2M-AS1            0            0            1          0          0
#
#           ENCSR619PCR_CTRL-1  ENCSR619PCR_CTRL-2  HLTF_KD-1  HLTF_KD-2  \
# Geneid
# A1BG                       1                   2          1          2
# A1BG-AS1                  49                  46         43         43
# A1CF                       1                   0          0          0
# A2M                        0                   1          0          2
# A2M-AS1                    1                   0          0          1
#
#           HNRNPA0_KD-1  HNRNPA0_KD-2  HNRNPA1_KD-1  HNRNPA1_KD-2  \
# Geneid
# A1BG                 5             8             1             1
# A1BG-AS1            41            39            37            58
# A1CF                 0             0             1             1
# A2M                  1             1           130            31
# A2M-AS1              1             0             0             1
#
#           ENCSR438MDN_CTRL-1  ENCSR438MDN_CTRL-2  HNRNPA2B1_KD-1  \
# Geneid
# A1BG                       2                   3               0
# A1BG-AS1                  70                  63              25
# A1CF                       3                   2               1
# A2M                      207                  63               0
# A2M-AS1                    1                   1               0
#
#           HNRNPA2B1_KD-2  HNRNPAB_KD-1  HNRNPAB_KD-2  HNRNPC_KD-1  \
# Geneid
# A1BG                   0             2             4            6
# A1BG-AS1              17            75            71           82
# A1CF                   0             0             0            1
# A2M                    0             0             0            0
# A2M-AS1                0             1             0            0
#
#           HNRNPC_KD-2  HNRNPF_KD-1  HNRNPF_KD-2  HNRNPK_KD-1  HNRNPK_KD-2  \
# Geneid
# A1BG                5            5            2            2            4
# A1BG-AS1           78           25           34           23           36
# A1CF                0            0            0            0            0
# A2M                 1            0            1            2            1
# A2M-AS1             1            2            0            0            0
#
#           ENCSR129RWD_CTRL-1  ENCSR129RWD_CTRL-2  HNRNPL_KD-1  HNRNPL_KD-2  \
# Geneid
# A1BG                       3                   2            2            1
# A1BG-AS1                  43                  35           93           73
# A1CF                       0                   1            0            0
# A2M                        0                   5            3            0
# A2M-AS1                    0                   1            3            0
#
#           HNRNPM_KD-1  HNRNPM_KD-2  HNRNPUL1_KD-1  HNRNPUL1_KD-2  HNRNPU_KD-1  \
# Geneid
# A1BG                1            0              2              4            0
# A1BG-AS1           44           26             35             54           84
# A1CF                0            0              0              0            0
# A2M                 1            1              0              0           65
# A2M-AS1             0            1              0              1            0
#
#           HNRNPU_KD-2  HSPD1_KD-1  HSPD1_KD-2  IGF2BP2_KD-1  IGF2BP2_KD-2  \
# Geneid
# A1BG                4           4           3             4             3
# A1BG-AS1           98          83          89            40            38
# A1CF                0           1           3             0             0
# A2M                65           2           0             1             1
# A2M-AS1             0           1           2             0             0
#
#           IGF2BP3_KD-1  IGF2BP3_KD-2  ILF2_KD-1  ILF2_KD-2  ILF3_KD-1  \
# Geneid
# A1BG                 2             5          1          5          1
# A1BG-AS1            36            56         48         44         32
# A1CF                 0             0          0          0          0
# A2M                  0             0          0          0          1
# A2M-AS1              1             1          1          0          0
#
#           ILF3_KD-2  KHDRBS1_KD-1  KHDRBS1_KD-2  KHSRP_KD-1  KHSRP_KD-2  \
# Geneid
# A1BG              1             0             0           3           0
# A1BG-AS1         41            35            42          37          38
# A1CF              0             0             0           0           0
# A2M               0             0             0           1           0
# A2M-AS1           1             0             1           0           0
#
#           KIF1C_KD-1  KIF1C_KD-2  KRR1_KD-1  KRR1_KD-2  LARP4_KD-1  \
# Geneid
# A1BG               1           7          1          3           6
# A1BG-AS1          15          49         36         23          44
# A1CF               0           0          0          0           0
# A2M                2           2          0          0           1
# A2M-AS1            0           0          1          1           0
#
#           LARP4_KD-2  LARP7_KD-1  LARP7_KD-2  LIN28B_KD-1  LIN28B_KD-2  \
# Geneid
# A1BG               3           4           2            2            2
# A1BG-AS1          59          43          34           49           43
# A1CF               0           0           0            0            1
# A2M                4           1           1            2            3
# A2M-AS1            2           0           1            0            1
#
#           LSM11_KD-1  LSM11_KD-2  MAGOH_KD-1  MAGOH_KD-2  MAK16_KD-1  \
# Geneid
# A1BG               0           1           4           5           2
# A1BG-AS1          22          36          46          39          23
# A1CF               0           2           0           0           0
# A2M                0           1           0           0           0
# A2M-AS1            0           0           1           1           1
#
#           MAK16_KD-2  MARK2_KD-1  MARK2_KD-2  MATR3_KD-1  MATR3_KD-2  \
# Geneid
# A1BG               6           1           1           4           0
# A1BG-AS1          61          33          41          67          55
# A1CF               0           1           0           0           1
# A2M                2           0          11           1           1
# A2M-AS1            3           2           0           0           0
#
#           MBNL1_KD-1  MBNL1_KD-2  METAP2_KD-1  METAP2_KD-2  MSI2_KD-1  \
# Geneid
# A1BG               6           5            4            2          5
# A1BG-AS1          68          30           55           55        109
# A1CF               0           0            0            4          0
# A2M                1           1           20           46          6
# A2M-AS1            2           0            0            1          1
#
#           MSI2_KD-2  MTPAP_KD-1  MTPAP_KD-2  NAA15_KD-1  NAA15_KD-2  \
# Geneid
# A1BG              4           3           2           5           3
# A1BG-AS1        142          79          93          32          25
# A1CF              0           0           0           0           0
# A2M               4          17          43           0           0
# A2M-AS1           2           2           1           1           0
#
#           NCBP2_KD-1  NCBP2_KD-2  NELFE_KD-1  NELFE_KD-2  NFX1_KD-1  \
# Geneid
# A1BG               2           3           6           4          1
# A1BG-AS1          47          39          61          89         38
# A1CF               0           0           0           0          0
# A2M                0           0           1           1          1
# A2M-AS1            0           0           0           2          0
#
#           NFX1_KD-2  NKRF_KD-1  NKRF_KD-2  NOL12_KD-1  NOL12_KD-2  NONO_KD-1  \
# Geneid
# A1BG              0          1          5           3           6          1
# A1BG-AS1         49         15         43          67          92         48
# A1CF              0          1          0           0           0          0
# A2M               0          2          9           1           0          0
# A2M-AS1           0          1          0           0           2          0
#
#           NONO_KD-2  NSUN2_KD-1  NSUN2_KD-2  NUFIP2_KD-1  NUFIP2_KD-2  \
# Geneid
# A1BG              2           6           4            0            2
# A1BG-AS1         62          71          86           50           57
# A1CF              0           4           1            0            1
# A2M               0         225          27            3            9
# A2M-AS1           0           3           1            0            0
#
#           NUP35_KD-1  NUP35_KD-2  NUSAP1_KD-1  NUSAP1_KD-2  PA2G4_KD-1  \
# Geneid
# A1BG               1           1            3            2           3
# A1BG-AS1          28          48           43           78          67
# A1CF               0           0            0            0           0
# A2M                1           0            2            3           0
# A2M-AS1            2           2            0            0           0
#
#           PA2G4_KD-2  PABPC1_KD-1  PABPC1_KD-2  PABPC4_KD-1  PABPC4_KD-2  \
# Geneid
# A1BG               0            5            1            1            5
# A1BG-AS1          56          145           58           21           18
# A1CF               0            0            0            0            0
# A2M                0            3            0            0            0
# A2M-AS1            0            0            2            0            0
#
#           PABPN1_KD-1  PABPN1_KD-2  PARN_KD-1  PARN_KD-2  PCBP1_KD-1  \
# Geneid
# A1BG                4            7          0          2           3
# A1BG-AS1           28           17         50         43          29
# A1CF                0            0          0          0           0
# A2M                 0            0          0          1           1
# A2M-AS1             0            0          0          0           0
#
#           PCBP1_KD-2  PCBP2_KD-1  PCBP2_KD-2  PHF6_KD-1  PHF6_KD-2  PKM_KD-1  \
# Geneid
# A1BG               4           2           7          4          4         2
# A1BG-AS1          27          33          48         64         40        84
# A1CF               0           0           0          0          0         2
# A2M                0           3           3          1          2        46
# A2M-AS1            0           0           0          1          0         0
#
#           PKM_KD-2  PNPT1_KD-1  PNPT1_KD-2  PPIG_KD-1  PPIG_KD-2  PPIL4_KD-1  \
# Geneid
# A1BG             3           5           3          3          5           3
# A1BG-AS1        79         135          70         89         68          61
# A1CF             1           0           0          0          0           0
# A2M             17           1           0          0          0           1
# A2M-AS1          0           0           3          0          2           0
#
#           PPIL4_KD-2  PPP1R8_KD-1  PPP1R8_KD-2  PRPF4_KD-1  PRPF4_KD-2  \
# Geneid
# A1BG               7            4            5           1           4
# A1BG-AS1          48           39           40          31          50
# A1CF               0            0            1           0           0
# A2M                0            0            0          44           3
# A2M-AS1            0            0            0           0           0
#
#           PRPF6_KD-1  PRPF6_KD-2  PSIP1_KD-1  PSIP1_KD-2  PTBP1_KD-1  \
# Geneid
# A1BG               4           0           6           2           5
# A1BG-AS1          66          54          62          35          51
# A1CF               0           0           0           0           0
# A2M                0           0           2           0           0
# A2M-AS1            0           2           0           0           3
#
#           PTBP1_KD-2  PUF60_KD-1  PUF60_KD-2  PUM1_KD-1  PUM1_KD-2  PUM2_KD-1  \
# Geneid
# A1BG               0           4           2          7          8          3
# A1BG-AS1          42         230          98         97        163        193
# A1CF               0           2           0          0          1          0
# A2M                0           3           1          1          0          1
# A2M-AS1            4           5           4          1          3          0
#
#           PUM2_KD-2  PUS1_KD-1  PUS1_KD-2  QKI_KD-1  QKI_KD-2  RAVER1_KD-1  \
# Geneid
# A1BG             10          2          3         2         1            3
# A1BG-AS1        163         16         18        28        20           14
# A1CF              0          2          1         1         0            0
# A2M               1         27         57         1         0            0
# A2M-AS1           1          0          0         0         0            1
#
#           RAVER1_KD-2  RBFOX2_KD-1  RBFOX2_KD-2  RBM15_KD-1  RBM15_KD-2  \
# Geneid
# A1BG                0            1            3           3           1
# A1BG-AS1           10           39           34          19          17
# A1CF                0            0            0           1           2
# A2M                 0            0            0          42          34
# A2M-AS1             1            1            0           0           1
#
#           RBM17_KD-1  RBM17_KD-2  RBM22_KD-1  RBM22_KD-2  RBM34_KD-1  \
# Geneid
# A1BG               8           4           1           4           6
# A1BG-AS1          89         129          73          81          74
# A1CF               0           0           2           0           0
# A2M                8          54           3           2           1
# A2M-AS1            0           0           3           1           1
#
#           RBM34_KD-2  RBM39_KD-1  RBM39_KD-2  RCC2_KD-1  RCC2_KD-2  \
# Geneid
# A1BG               7           2           7          0          2
# A1BG-AS1          53          40          27         33         39
# A1CF               0           0           0          0          0
# A2M                0           1           1          0          0
# A2M-AS1            1           0           0          0          0
#
#           RECQL_KD-1  RECQL_KD-2  RPS10_KD-1  RPS10_KD-2  RPS19_KD-1  \
# Geneid
# A1BG               3           0           2           0           3
# A1BG-AS1          31          14          27          38          54
# A1CF               0           0           0           0           0
# A2M                1           0           0           1           0
# A2M-AS1            1           0           0           0           0
#
#           RPS19_KD-2  RPS3A_KD-1  RPS3A_KD-2  RRP9_KD-1  RRP9_KD-2  RTF1_KD-1  \
# Geneid
# A1BG               5           5           1          2          3          3
# A1BG-AS1          84          54          62         37         49         53
# A1CF               0           0           0          0          0          0
# A2M                2           0           0          0          0          0
# A2M-AS1            2           3           1          0          1          0
#
#           RTF1_KD-2  SAFB2_KD-1  SAFB2_KD-2  ENCSR154OBA_CTRL-1  \
# Geneid
# A1BG              3           5           7                   2
# A1BG-AS1         54          61          65                  75
# A1CF              0           4           3                   3
# A2M               1         290         436                 344
# A2M-AS1           2           1           0                   2
#
#           ENCSR154OBA_CTRL-2  SART3_KD-1  SART3_KD-2  SBDS_KD-1  SBDS_KD-2  \
# Geneid
# A1BG                       2           9           3          2          2
# A1BG-AS1                  42          54          49         53         51
# A1CF                       5           3           0          0          0
# A2M                      493           4           3          1          1
# A2M-AS1                    1           0           2          3          3
#
#           SERBP1_KD-1  SERBP1_KD-2  SF1_KD-1  SF1_KD-2  SF3A3_KD-1  \
# Geneid
# A1BG                2            0         4         1           2
# A1BG-AS1           34           39        14        26          93
# A1CF                0            0         0         0           1
# A2M                 2            2         5         3           9
# A2M-AS1             0            1         1         0           2
#
#           SF3A3_KD-2  SF3B4_KD-1  SF3B4_KD-2  SFPQ_KD-1  SFPQ_KD-2  SLBP_KD-1  \
# Geneid
# A1BG               1           3           1          3          3          3
# A1BG-AS1         115          17          12         49         43         47
# A1CF               2           0           0          0          0          0
# A2M               46           0           1          0          0          0
# A2M-AS1            0           0           0          0          0          0
#
#           SLBP_KD-2  SLTM_KD-1  SLTM_KD-2  SMN1_KD-1  SMN1_KD-2  SMNDC1_KD-1  \
# Geneid
# A1BG              1          3          2          2          3            4
# A1BG-AS1         42         30         36         59         41           50
# A1CF              0          0          0          0          0            0
# A2M               0          1          0          1          1            2
# A2M-AS1           0          0          2          0          0            0
#
#           SMNDC1_KD-2  SND1_KD-1  SND1_KD-2  SNRNP200_KD-1  SNRNP200_KD-2  \
# Geneid
# A1BG                0          1          4              3              0
# A1BG-AS1           53         20         22             26             10
# A1CF                0          1          0              0              0
# A2M                 0          0          0              0              1
# A2M-AS1             2          2          0              0              0
#
#           SRFBP1_KD-1  SRFBP1_KD-2  SRP68_KD-1  SRP68_KD-2  SRPK2_KD-1  \
# Geneid
# A1BG                2            1           2           0           2
# A1BG-AS1           41           38          49          37          71
# A1CF                0            0           0           0           0
# A2M                 0            1           0           1          23
# A2M-AS1             0            0           0           0           0
#
#           SRPK2_KD-2  SRSF1_KD-1  SRSF1_KD-2  SSB_KD-1  SSB_KD-2  SSRP1_KD-1  \
# Geneid
# A1BG               5           5          10         0         2           1
# A1BG-AS1          77          48          30        40        33          54
# A1CF               0           3           0         0         0           8
# A2M               31           0           3         0         0         350
# A2M-AS1            0           1           0         1         0           2
#
#           SSRP1_KD-2  STAU1_KD-1  STAU1_KD-2  STIP1_KD-1  STIP1_KD-2  \
# Geneid
# A1BG               5           1           2           0           7
# A1BG-AS1          89          54          68          66          61
# A1CF               4           1           0           0           0
# A2M               59           8          26           4           3
# A2M-AS1            0           2           4           4           0
#
#           SUB1_KD-1  SUB1_KD-2  SUCLG1_KD-1  SUCLG1_KD-2  SUGP2_KD-1  \
# Geneid
# A1BG              1          3            7            8           0
# A1BG-AS1         59         59           71           90          34
# A1CF              0          1            0            0           0
# A2M               0          0            0            0           2
# A2M-AS1           1          0            1            1           0
#
#           SUGP2_KD-2  SUPT6H_KD-1  SUPT6H_KD-2  SUPV3L1_KD-1  SUPV3L1_KD-2  \
# Geneid
# A1BG               6            3            2             6             0
# A1BG-AS1          48           49           47            46            64
# A1CF               0            0            0             0             0
# A2M                0            2            1             0             1
# A2M-AS1            0            0            0             0             1
#
#           TAF15_KD-1  TAF15_KD-2  TARDBP_KD-1  TARDBP_KD-2  TBRG4_KD-1  \
# Geneid
# A1BG               5           3            2            1           4
# A1BG-AS1          10          17           78           84          17
# A1CF               0           0            0            1           0
# A2M                0           0            3            0           0
# A2M-AS1            2           1            0            0           0
#
#           TBRG4_KD-2  TFIP11_KD-1  TFIP11_KD-2  TIA1_KD-1  TIA1_KD-2  \
# Geneid
# A1BG               1            0            0          2          4
# A1BG-AS1          27           49           36         72         47
# A1CF               0            0            0          1          0
# A2M                0            1            0          0          0
# A2M-AS1            0            1            0          0          0
#
#           TIAL1_KD-1  TIAL1_KD-2  TRIM56_KD-1  TRIM56_KD-2  TRIP6_KD-1  \
# Geneid
# A1BG               2           6            1            1           2
# A1BG-AS1          56          48           32           55          74
# A1CF               2           0            0            0           0
# A2M                0           0            0            0          82
# A2M-AS1            1           1            0            2           1
#
#           TRIP6_KD-2  TROVE2_KD-1  TROVE2_KD-2  ENCSR092WKG_CTRL-1  \
# Geneid
# A1BG               2            5            5                   5
# A1BG-AS1          65           85          101                  96
# A1CF               0            2            2                   1
# A2M               14          143          193                  70
# A2M-AS1            0            0            2                   2
#
#           ENCSR092WKG_CTRL-2  TUFM_KD-1  TUFM_KD-2  U2AF1_KD-1  U2AF1_KD-2  \
# Geneid
# A1BG                       2          1          2           1           2
# A1BG-AS1                  95         42         54          16          10
# A1CF                       4          0          1           0           0
# A2M                      354          8          3           0           2
# A2M-AS1                    3          0          0           0           0
#
#           U2AF2_KD-1  U2AF2_KD-2  UBE2L3_KD-1  UBE2L3_KD-2  UCHL5_KD-1  \
# Geneid
# A1BG               1           0            5            6           2
# A1BG-AS1          25          13          128          226          61
# ...
# Geneid
# A1BG               9           8          56          36          15
# A1BG-AS1           0           0           2           3           2
# A1CF            1726        1498        4240        4026        2188
# A2M           162960      136319      238371      222848      196068
# A2M-AS1           19          25          13          13          31
#
#           RBM27_KD-2  RBM34_KD-1  RBM34_KD-2  RBM39_KD-1  RBM39_KD-2  \
# Geneid
# A1BG              23          23          14          10          20
# A1BG-AS1           2           0           0           0           0
# A1CF            3463        4052        3400        5920        5317
# A2M           317188      249437      215345      215648      184445
# A2M-AS1           50          19          18           5          15
#
#           RBM47_KD-1  RBM47_KD-2  RCC2_KD-1  RCC2_KD-2  RECQL_KD-1  \
# Geneid
# A1BG              10          15         23          4          48
# A1BG-AS1           0           0          0          0           1
# A1CF            1824        1659       3340       1249        4498
# A2M           185195      194697     169769      63254      206269
# A2M-AS1           13           5         53         16          40
#
#           RECQL_KD-2  RPL23A_KD-1  RPL23A_KD-2  RPS10_KD-1  RPS10_KD-2  \
# Geneid
# A1BG              55           11           21          40          30
# A1BG-AS1           1            0            0           0           0
# A1CF            4263         2247         2800        3868        3475
# A2M           201546       153053       202925      289847      267405
# A2M-AS1           45           22           24          23          12
#
#           RPS19_KD-1  RPS19_KD-2  RPS2_KD-1  RPS2_KD-2  RPS3A_KD-1  \
# Geneid
# A1BG              15          27         25         25          56
# A1BG-AS1           1           1          0          0           0
# A1CF            1910        1591       2342       2632        3740
# A2M            99520       84440     212973     231584      377359
# A2M-AS1           41          45         41         29          15
#
#           RPS3A_KD-2  RPS5_KD-1  RPS5_KD-2  RRP9_KD-1  RRP9_KD-2  RTF1_KD-1  \
# Geneid
# A1BG              82         14          7         11         12         11
# A1BG-AS1           1          0          1          2          2          1
# A1CF            3693       2673       1942       2120       2037       4797
# A2M           374474     183098     144103     195387     199632     207297
# A2M-AS1           19         33         39         10         10         40
#
#           RTF1_KD-2  SAFB2_KD-1  SAFB2_KD-2  SART3_KD-1  SART3_KD-2  \
# Geneid
# A1BG             12          16          28          18          20
# A1BG-AS1          0           0           1           0           0
# A1CF           4044        2883        2939        1946        2382
# A2M          164988      120398      123408      163567      195396
# A2M-AS1          26          12          19          13          13
#
#           SBDS_KD-1  SBDS_KD-2  SERBP1_KD-1  SERBP1_KD-2  SF1_KD-1  SF1_KD-2  \
# Geneid
# A1BG             22         14           46           42        18        15
# A1BG-AS1          0          0            0            2         1         0
# A1CF           2760       2039         3916         2382      5180      5426
# A2M          244744     219994       299739       193398    197683    192457
# A2M-AS1          12          5           20           16        17        18
#
#           SF3A3_KD-1  SF3A3_KD-2  ENCSR691IVR_CTRL-1  ENCSR691IVR_CTRL-2  \
# Geneid
# A1BG              43          37                  54                  45
# A1BG-AS1           1           1                   1                   1
# A1CF            6854        5230                6016                5938
# A2M           332340      205791              313361              315351
# A2M-AS1           13          11                  16                  19
#
#           SF3B1_KD-1  SF3B1_KD-2  SF3B4_KD-1  SF3B4_KD-2  SFPQ_KD-1  \
# Geneid
# A1BG              21          19          34          16          6
# A1BG-AS1           0           0           1           1          0
# A1CF            6100        5616        4482        4060       2132
# A2M           163106      138679      172956      162321     184514
# A2M-AS1           11           5          42          39         10
#
#           SFPQ_KD-2  SLBP_KD-1  SLBP_KD-2  SLTM_KD-1  SLTM_KD-2  SMN1_KD-1  \
# Geneid
# A1BG              9         37         24         36         43          8
# A1BG-AS1          0          1          0          0          0          0
# A1CF           2273       3455       3613       4381       3652       1927
# A2M          210758     253007     269354     193611     174173      77162
# A2M-AS1          19         17         22         16         14         38
#
#           SMN1_KD-2  SMNDC1_KD-1  SMNDC1_KD-2  SND1_KD-1  SND1_KD-2  \
# Geneid
# A1BG              6            9           13         20         15
# A1BG-AS1          1            2            0          0          0
# A1CF           2147         3338         3280       2935       2985
# A2M           93872       253642       267324     216368     209120
# A2M-AS1          49           14           14         22         15
#
#           SNRNP200_KD-1  SNRNP200_KD-2  SNRNP70_KD-1  SNRNP70_KD-2  \
# Geneid
# A1BG                 19             15             5            14
# A1BG-AS1              0              0             0             0
# A1CF               4872           3234          1801          3070
# A2M              336291         236813        349279        481673
# A2M-AS1              13              8            20            18
#
#           SRFBP1_KD-1  SRFBP1_KD-2  SRP68_KD-1  SRP68_KD-2  SRSF1_KD-1  \
# Geneid
# A1BG                6            7          26          11          20
# A1BG-AS1            1            0           1           1           0
# A1CF             4124         2563        3245        3829        7741
# A2M             77123        50776      200683      230878       87649
# A2M-AS1            23           21          15          14          44
#
#           SRSF1_KD-2  SRSF3_KD-1  SRSF3_KD-2  SRSF5_KD-1  SRSF5_KD-2  \
# Geneid
# A1BG              18           5           6          12          22
# A1BG-AS1           0           2           0           0           0
# A1CF            9019        2529        3407        2171        2488
# A2M           100626       48425       84744      217526      254681
# A2M-AS1           45          29          34          18          14
#
#           SRSF9_KD-1  SRSF9_KD-2  SSB_KD-1  SSB_KD-2  SSRP1_KD-1  SSRP1_KD-2  \
# Geneid
# A1BG              24          19        81        52          18          20
# A1BG-AS1           0           0         1         1           0           0
# A1CF            3086        3175      6590      6131        3059        4089
# A2M           311684      358690    385781    354533      294125      425663
# A2M-AS1           11           8        32        34           2          13
#
#           STAU1_KD-1  STAU1_KD-2  STIP1_KD-1  STIP1_KD-2  SUB1_KD-1  \
# Geneid
# A1BG              16          54          16          15          6
# A1BG-AS1           0           0           0           1          1
# A1CF            1930        5487        1181        1304       3067
# A2M           109662      366485      163698      168256     276604
# A2M-AS1            4          17           4           4         11
#
#           SUB1_KD-2  SUCLG1_KD-1  SUCLG1_KD-2  SUGP2_KD-1  SUGP2_KD-2  \
# Geneid
# A1BG              7           18           14          24          24
# A1BG-AS1          0            0            0           0           2
# A1CF           2405         2525         3138        5640        5894
# A2M          248228       164220       196596      463891      452410
# A2M-AS1           4           34           39          20          16
#
#           SUPT6H_KD-1  SUPT6H_KD-2  SUPV3L1_KD-1  SUPV3L1_KD-2  TAF15_KD-1  \
# Geneid
# A1BG               31           34            36            27          17
# A1BG-AS1            1            0             1             2           0
# A1CF             3354         5559          6503          5020        2534
# A2M            286249       464991        338256        244351      255435
# A2M-AS1             6            7            38            33          44
#
#           TAF15_KD-2  TARDBP_KD-1  TARDBP_KD-2  TBRG4_KD-1  TBRG4_KD-2  \
# Geneid
# A1BG              22           23           24         120          94
# A1BG-AS1           0            0            3           0           1
# A1CF            2323         4808         4626        6795        4957
# A2M           226411       349511       306882      710067      591802
# A2M-AS1           48            9           12           8           8
#
#           TFIP11_KD-1  TFIP11_KD-2  TIA1_KD-1  TIA1_KD-2  TIAL1_KD-1  \
# Geneid
# A1BG               17            8         41         41          43
# A1BG-AS1            0            1          0          0           2
# A1CF             1721          736       3205       2512        3701
# A2M            252793       121568     299555     267434      132591
# A2M-AS1             7            3         14         10          19
#
#           TIAL1_KD-2  TRA2A_KD-1  TRA2A_KD-2  TRIM56_KD-1  TRIM56_KD-2  \
# Geneid
# A1BG              46          15          15           21           21
# A1BG-AS1           0           0           1            0            0
# A1CF            2746        2940        2878         2687         2189
# A2M           107404      113295      117703       309219       241382
# A2M-AS1           11          32          40            8           11
#
#           TROVE2_KD-1  TROVE2_KD-2  TUFM_KD-1  TUFM_KD-2  U2AF1_KD-1  \
# Geneid
# A1BG                8            5         26         19          41
# A1BG-AS1            0            0          1          1           0
# A1CF             1489         1636       2464       2205        6230
# A2M             75516        83280     390984     386448      205847
# A2M-AS1            19           19          7          8          23
#
#           U2AF1_KD-2  U2AF2_KD-1  U2AF2_KD-2  UBE2L3_KD-1  UBE2L3_KD-2  \
# Geneid
# A1BG              24          12          11           19           32
# A1BG-AS1           0           0           1            0            0
# A1CF            3937        7584        6391         2341         2526
# A2M           118872      192003      157207       172816       216796
# A2M-AS1           11          12           5            9            9
#
#           UCHL5_KD-1  UCHL5_KD-2  UPF1_KD-1  UPF1_KD-2  UPF2_KD-1  UPF2_KD-2  \
# Geneid
# A1BG               4           3         72         55         46         15
# A1BG-AS1           0           0          2          1          0          0
# A1CF             433         414       4536       4182       3683       1699
# A2M            51024       46589     272839     250709     231614     128906
# A2M-AS1           11          15         16         17         27         20
#
#           UTP18_KD-1  UTP18_KD-2  UTP3_KD-1  UTP3_KD-2  WDR3_KD-1  WDR3_KD-2  \
# Geneid
# A1BG              54          33         18         19         22         16
# A1BG-AS1           0           1          0          0          0          0
# A1CF            4612        4709       2757       3469       3428       2434
# A2M           275938      275259     144243     207237     179096     128201
# A2M-AS1           12           5         15         23         10          9
#
#           WRN_KD-1  WRN_KD-2  XPO1_KD-1  XPO1_KD-2  XPO5_KD-1  XPO5_KD-2  \
# Geneid
# A1BG            21        28         61        122         14         18
# A1BG-AS1         0         1          1          6          0          0
# A1CF          2854      2208       2628       8794       2185       2028
# A2M         120530    100314     135288     432088     176728     150358
# A2M-AS1         17         9          9         27         16          9
#
#           XRCC5_KD-1  XRCC5_KD-2  XRCC6_KD-1  XRCC6_KD-2  XRN1_KD-1  \
# Geneid
# A1BG               9           5           5           7         67
# A1BG-AS1           0           0           0           1          1
# A1CF            2921        2393        4050        3728       7864
# A2M           181148      161255      125191      121806     338863
# A2M-AS1           26          21          34          35         24
#
#           XRN1_KD-2  XRN2_KD-1  XRN2_KD-2  YBX3_KD-1  YBX3_KD-2  YTHDC2_KD-1  \
# Geneid
# A1BG             56         39         35         17         22           29
# A1BG-AS1          3          2          0          0          0            0
# A1CF           7621       2979       3033       2920       3192         2760
# A2M          311034     147136     144334     141142     157434        58428
# A2M-AS1          18         36         43         15         22           25
#
#           YTHDC2_KD-2  YWHAG_KD-1  YWHAG_KD-2  ZC3H8_KD-1  ZC3H8_KD-2  \
# Geneid
# A1BG               19          23          33          15          22
# A1BG-AS1            0           0           0           0           0
# A1CF             1826        2266        2056        2144        2968
# A2M             39962      207138      202359       92780      134102
# A2M-AS1            12           8           4          17          40
#
#           ZNF622_KD-1  ZNF622_KD-2  ZRANB2_KD-1  ZRANB2_KD-2
# Geneid
# A1BG               43           46           30           21
# A1BG-AS1            0            1            0            0
# A1CF             5677         5263         3397         3480
# A2M            585098       615964       208762       216075
# A2M-AS1             4            7            8           12

# %% [markdown]
# ## Output Gene Lengths

# %%
# take any counts file as they have the same gene metadata 
random_counts_file = glob.glob("../output/1_experiment_counts/*.txt")[0]

# read file and subset to gene ID and length columns
# output to file so that it can be used later for gene-length normalization
pd.read_csv(random_counts_file, sep="\t", skiprows=1)[["Geneid", "Length"]].to_csv("../output/2_final_raw_counts_matrices/gene_lengths.tsv", sep="\t", index=False)
