# %%
import pandas as pd
pd.set_option('display.max_rows', 1000000)
pd.set_option('display.max_columns', 1000000)
pd.set_option('display.max_colwidth', 10000000)

from IPython.core.interactiveshell import InteractiveShell
InteractiveShell.ast_node_interactivity = "all"

# %%
hepg2_input_binding_data_path = "/project/PlatigLab/data/collaborators/BWH/input_binding_data_and_INCORRECT_SHAP_toy_data_2024-07/input_binding_data/HepG2-50-50-50/regression_HepG2_binding_psi_psip_KD.csv.gz"

k562_input_binding_data_path = "/project/PlatigLab/data/collaborators/BWH/input_binding_data_and_INCORRECT_SHAP_toy_data_2024-07/input_binding_data/K562-50-50-50/regression_K562_binding_psi_psip_KD.csv.gz"

# %%
pd.read_csv(
    hepg2_input_binding_data_path, 
    compression="gzip",
    sep=",", 
).head()
