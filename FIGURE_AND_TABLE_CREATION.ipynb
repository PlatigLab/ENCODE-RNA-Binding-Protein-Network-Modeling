# %% [markdown]
# <h1 style="color: teal; font-weight: bold; font-size: 50px;">Reproduction of Main Figures, Supplementary Figures, and Supplementary Tables</h1>

# %% [markdown]
# <h1 style="color: gold; font-weight: bold; font-size: 24px;">If you want to reproduce these tables/figures starting from raw data, you must run all the steps as described in the "./REPRODUCTION.MD" file.<br><br>However, if you would like to see all these outputs using the cached data generated from my run (and sync'd to GitHub), you can begin immmediately.</h1>

# %% [markdown]
# <h1 style="color: Coral; font-weight: bold; font-size: 50px;">Loading Necessary Packages/Options</h1>

# %%
import os, importlib, pprint, base64, glob

from IPython.core.interactiveshell import InteractiveShell
InteractiveShell.ast_node_interactivity = "all"

from IPython.display import IFrame

import pandas as pd
pd.set_option('display.max_rows', 200)
pd.set_option('display.max_columns', 5000)
pd.set_option('display.max_colwidth', 10000)

import polars as pl 
_=pl.Config.set_tbl_cols(5000)
_=pl.Config.set_tbl_rows(200)
_=pl.Config.set_tbl_width_chars(10000)
_=pl.Config.set_fmt_str_lengths(10000)

import papermill

from pathlib import Path

# %%
REPO_ROOT_DIR = os.getcwd()
REPO_ROOT_DIR

FEATURE_SHAP_CLASS_DIR = f"{REPO_ROOT_DIR}/analysis/06_first_order_SHAP_analysis/code/"
INTERACTION_SHAP_CLASS_DIR = f"{REPO_ROOT_DIR}/analysis/07_second_order_SHAP_analysis/2_analyze_shap_interaction_values/code/"
CRISPR_ANALYSIS_DIR = f"{REPO_ROOT_DIR}/analysis/08_reece_anderson_biological_validations/1_CRISPR_CTRL_SHAP/"

# %% [markdown]
# ## Custom Classes

# %%
os.chdir(FEATURE_SHAP_CLASS_DIR)

feature_shap_class = getattr(
    importlib.import_module("1_first_order_shap_investigator"), 
    "FirstOrderShapInvestigator"
)

feature_shap_analyzer = feature_shap_class()
feature_shap_analyzer.hash_metadata

# %%
os.chdir(INTERACTION_SHAP_CLASS_DIR)

interaction_shap_class = getattr(
    importlib.import_module("2_second_order_shap_analysis"), 
    "SecondOrderShapNetworkAnalyzer"
)

interaction_shap_analyzer = interaction_shap_class()
pprint.pprint(
    interaction_shap_analyzer.CONFIG, 
    indent=4
)

# %% [markdown]
# <h1 style="color: Coral; font-weight: bold; font-size: 50px;">Main Figures</h1>

# %% [markdown]
# <h1 style="color: crimson; font-weight: bold; font-size: 40px;">1B</h1>

# %%
os.chdir(FEATURE_SHAP_CLASS_DIR)

feature_shap_analyzer.create_model_average_performance_table()

# %% [markdown]
# <h1 style="color: crimson; font-weight: bold; font-size: 40px;">1C</h1>

# %%
os.chdir(FEATURE_SHAP_CLASS_DIR)

feature_shap_analyzer.plot_actual_vs_predicted_as_kde(bw_adjust=1.0, levels=30)

# %% [markdown]
# <h1 style="color: crimson; font-weight: bold; font-size: 40px;">2A</h1>

# %%
os.chdir(FEATURE_SHAP_CLASS_DIR)

feature_shap_analyzer.plot_dpsi_vs_local_SHAP_mcc_as_barplot()

# %% [markdown]
# <h1 style="color: crimson; font-weight: bold; font-size: 40px;">2B</h1>

# %%
os.chdir(
    f"{REPO_ROOT_DIR}/analysis/08_reece_anderson_biological_validations/1_CRISPR_CTRL_SHAP/Figures/"
)

_ = papermill.execute_notebook(
    "figure_2_B_generation.ipynb",
    "/dev/null"
)

feature_names = ["EIF4E_2", "PRPF8_5"]

for feature in feature_names: 
    with open(f"./{feature}_binding_scatterplot.pdf", 'rb') as file:
        base64_pdf = base64.b64encode(file.read()).decode('utf-8')
    
    IFrame(
        f"data:application/pdf;base64,{base64_pdf}",
        width = 650, 
        height=  500
    )

# %% [markdown]
# <h1 style="color: crimson; font-weight: bold; font-size: 40px;">3A</h1>

# %%
os.chdir(FEATURE_SHAP_CLASS_DIR)

feature_shap_analyzer.plot_signed_global_SHAP_summary(binding_unique="Unique-Binding")

# %% [markdown]
# <h1 style="color: crimson; font-weight: bold; font-size: 40px;">3B</h1>

# %%
os.chdir(FEATURE_SHAP_CLASS_DIR)

feature_shap_analyzer.plot_signed_global_SHAP_row_min_and_max_vignette(top_n=10, binding_unique="Unique-Binding")

# %% [markdown]
# <h1 style="color: crimson; font-weight: bold; font-size: 40px;">4B</h1>

# %%
os.chdir(
    f"{REPO_ROOT_DIR}/analysis/08_reece_anderson_biological_validations/2_RBP_Activity/"
)

_ = papermill.execute_notebook(
    "figures_4B_4C.ipynb",
    "/dev/null"
)

with open(f"./rbp_activity_heatmap.pdf", 'rb') as file:
    base64_pdf = base64.b64encode(file.read()).decode('utf-8')

IFrame(
    f"data:application/pdf;base64,{base64_pdf}",
    width = 800, 
    height=  750
)

# %% [markdown]
# <h1 style="color: crimson; font-weight: bold; font-size: 40px;">4C</h1>

# %%
os.chdir(
    f"{REPO_ROOT_DIR}/analysis/08_reece_anderson_biological_validations/2_RBP_Activity/"
)

_ = papermill.execute_notebook(
    "figures_4B_4C.ipynb",
    "/dev/null"
)

for cell_line in interaction_shap_analyzer.CONFIG["CELL_LINES"]:

    with open(f"./{cell_line}_scatterplot.pdf", 'rb') as file:
        base64_pdf = base64.b64encode(file.read()).decode('utf-8')
    
    IFrame(
        f"data:application/pdf;base64,{base64_pdf}",
        width = 800, 
        height=  600
    )

# %% [markdown]
# <h1 style="color: crimson; font-weight: bold; font-size: 40px;">5A</h1>

# %%
os.chdir(INTERACTION_SHAP_CLASS_DIR)

interaction_shap_analyzer.plot_interaction_sign_concordance_over_shap_thresholds()

# %% [markdown]
# <h1 style="color: crimson; font-weight: bold; font-size: 40px;">5B</h1>

# %%
os.chdir(INTERACTION_SHAP_CLASS_DIR)

interaction_shap_analyzer.plot_selected_roc_and_pr_curves_for_main_figure(metric="Bound-Only")

# %% [markdown]
# <h1 style="color: crimson; font-weight: bold; font-size: 40px;">5C</h1>

# %%
os.chdir(INTERACTION_SHAP_CLASS_DIR)

interaction_shap_analyzer.plot_psi_distributions_for_interaction_feature(
        interaction_feature = "CSTF2T_3-ILF3_3-interaction-shap", 
        cell_lines = interaction_shap_analyzer.CONFIG["CELL_LINES"], 
    )

# %% [markdown]
# <h1 style="color: crimson; font-weight: bold; font-size: 40px;">5D</h1>

# %%
os.chdir(INTERACTION_SHAP_CLASS_DIR)

interaction_shap_analyzer.plot_psi_distributions_for_interaction_feature(
        interaction_feature = "HNRNPM_2-SUB1_5-interaction-shap",
        cell_lines = ["HepG2"]
    )

# %% [markdown]
# <h1 style="color: crimson; font-weight: bold; font-size: 40px;">5E</h1>

# %%
os.chdir(INTERACTION_SHAP_CLASS_DIR)

interaction_shap_analyzer.plot_psi_distributions_for_interaction_feature(
        interaction_feature = "HLTF_2-PRPF8_4-interaction-shap", 
        cell_lines =["K562"], 
    )

# %% [markdown]
# <h1 style="color: Coral; font-weight: bold; font-size: 50px;">Supplementary Figures</h1>

# %% [markdown]
# <h1 style="color: crimson; font-weight: bold; font-size: 40px;">S1A</h1>

# %%
os.chdir(FEATURE_SHAP_CLASS_DIR)

feature_shap_analyzer.plot_binding_sum_quantiles()

# %% [markdown]
# <h1 style="color: crimson; font-weight: bold; font-size: 40px;">S1B</h1>

# %%
os.chdir(FEATURE_SHAP_CLASS_DIR)

feature_shap_analyzer.plot_actual_vs_predicted_for_best_models(underlying_data="All-Data")

# %% [markdown]
# <h1 style="color: crimson; font-weight: bold; font-size: 40px;">S1C</h1>

# %%
os.chdir(FEATURE_SHAP_CLASS_DIR)

feature_shap_analyzer.show_3_and_4_significance_for_bound_global_SHAP()

# %% [markdown]
# <h1 style="color: crimson; font-weight: bold; font-size: 40px;">S1D</h1>

# %%
os.chdir(FEATURE_SHAP_CLASS_DIR)

feature_shap_analyzer.plot_position_signed_average_barplot()

# %% [markdown]
# <h1 style="color: crimson; font-weight: bold; font-size: 40px;">S2</h1>

# %%
os.chdir(FEATURE_SHAP_CLASS_DIR)

feature_shap_analyzer.plot_alphabetical_glossary_heatmaps_for_signed_bound_mean_shap()

# %% [markdown]
# <h1 style="color: crimson; font-weight: bold; font-size: 40px;">S3A</h1>

# %%
os.chdir(FEATURE_SHAP_CLASS_DIR)

feature_shap_analyzer.plot_RBP_positional_preference_and_signed_bound_global_shap(
    rbps = [
        "ILF3", 
        "MATR3", 
        "AGGF1", 
        "PTBP1", 
        "HNRNPM", 
        "QKI", 
        "DDX3X"
    ],

    save_fig_suffix = "main_effect_positional_preference"
)

# %% [markdown]
# <h1 style="color: crimson; font-weight: bold; font-size: 40px;">S3B</h1>

# %%
os.chdir(FEATURE_SHAP_CLASS_DIR)

feature_shap_analyzer.create_scatterplot_of_positional_preference_vs_signed_bound_global_shap()

# %% [markdown]
# <h1 style="color: crimson; font-weight: bold; font-size: 40px;">S4</h1>

# %%
os.chdir(INTERACTION_SHAP_CLASS_DIR)

interaction_shap_analyzer.plot_all_roc_and_pr_curve_combinations_for_rbp_specific_sum_value(metric="Bound-Only")

# %% [markdown]
# <h1 style="color: crimson; font-weight: bold; font-size: 40px;">S5A</h1>

# %%
os.chdir(INTERACTION_SHAP_CLASS_DIR)

interaction_shap_analyzer.plot_average_importance_between_positions()

# %% [markdown]
# <h1 style="color: crimson; font-weight: bold; font-size: 40px;">S5B</h1>

# %%
os.chdir(INTERACTION_SHAP_CLASS_DIR)

interaction_shap_analyzer.plot_psi_distributions_for_interaction_feature(
        interaction_feature = "DDX3X_2-PTBP1_3-interaction-shap", 
        cell_lines = interaction_shap_analyzer.CONFIG["CELL_LINES"], 
        save_fig_folder = "cell_line_concordant"
    )

# %% [markdown]
# <h1 style="color: crimson; font-weight: bold; font-size: 40px;">S5C</h1>

# %%
os.chdir(INTERACTION_SHAP_CLASS_DIR)

interaction_shap_analyzer.plot_psi_distributions_for_interaction_feature(
        interaction_feature = "QKI_3-U2AF2_3-interaction-shap", 
        cell_lines = interaction_shap_analyzer.CONFIG["CELL_LINES"], 
        save_fig_folder = "cell_line_concordant"
    )

# %% [markdown]
# <h1 style="color: Coral; font-weight: bold; font-size: 50px;">Supplementary Tables</h1>

# %% [markdown]
# <h1 style="color: crimson; font-weight: bold; font-size: 40px;">Table S1</h1>

# %%
os.chdir(
    f"{REPO_ROOT_DIR}/analysis/08_reece_anderson_biological_validations/1_CRISPR_CTRL_SHAP/Analyses/"
)

_ = papermill.execute_notebook(
    "supp_table_S1.ipynb",
    "/dev/null"
)

table_s1 = glob.glob("*.tsv")
assert len(table_s1) ==1

table_s1 = Path(table_s1[0]).resolve()
print(f'Supplementary Table S1 can be found at the following path: {table_s1}')

table_s1 = pd.read_csv(table_s1, sep="\t")
table_s1

# %% [markdown]
# <h1 style="color: crimson; font-weight: bold; font-size: 40px;">Table S2</h1>

# %%
os.chdir(FEATURE_SHAP_CLASS_DIR)

table_s2 = Path(feature_shap_analyzer.SUPPLEMENTARY_TABLES["shap_metrics_and_activity_score"]).resolve()
print(f"Supplementary Table S2 can be found at the following path: {table_s2}")

table_s2 = feature_shap_analyzer.make_composite_table_of_individual_feature_shap_metrics_and_activity_scores()
table_s2

# %% [markdown]
# <h1 style="color: crimson; font-weight: bold; font-size: 40px;">Table S3</h1>

# %%
os.chdir(INTERACTION_SHAP_CLASS_DIR)

interaction_shap_analyzer.create_composite_shap_table()

table_s3 = Path(interaction_shap_analyzer.CONFIG["SUPPLEMENTARY_TABLES"]["composite_shap_metric_table"]).resolve()
print(f'Supplementary Table S3 can be found at the following path: {table_s3}')

table_s3 = pd.read_csv(table_s3, sep="\t")
table_s3

# %% [markdown]
# <h1 style="color: crimson; font-weight: bold; font-size: 40px;">Table S4</h1>

# %%
os.chdir(INTERACTION_SHAP_CLASS_DIR)

table_s4 = Path(interaction_shap_analyzer.CONFIG["SUPPLEMENTARY_TABLES"]['cell_line_concordant_interactions_screening_table']).resolve()
print(f'Supplementary Table S4 can be found at the following path: {table_s4}')

table_s4 = interaction_shap_analyzer.create_table_from_systematic_screen_of_interactions_for_psi_changes()
table_s4.head()

# %% [markdown]
# <h1 style="color: crimson; font-weight: bold; font-size: 40px;">Table S5</h1>

# %%
os.chdir(INTERACTION_SHAP_CLASS_DIR)

table_s5 = Path(interaction_shap_analyzer.CONFIG["SUPPLEMENTARY_TABLES"]['cleaned_cell_line_specific_interaction_greater_than_individual_effects_table']).resolve()
print(f'Supplementary Table S5 can be found at the following path: {table_s5}')

table_s5 = interaction_shap_analyzer.create_cleaned_table_of_cell_line_specific_interaction_larger_than_individual_effects_table()
table_s5.head()
